# %%
import serial
import time
import math
import csv
from gekko import GEKKO
import numpy as np

ser = serial.Serial(
    port='COM6',
    baudrate=115200,
    timeout=1
)

# List to store results
results = []

def send_command(command):
    ser.reset_input_buffer()  # Clear any pending input
    ser.write(f"{command}\r\n".encode())
    time.sleep(0.2)  # Wait for processing
    
    while ser.in_waiting:
        response = ser.readline().decode().strip()
        if response:  # Only print non-empty responses
            print(f"Pico response: {response}")
            # Check if response contains MPU6050 angles
            if response.startswith("MPU:"):
                return [float(x) for x in response[4:].split()]
    return None

def send_angles(pitch, yaw):
    command = f"ANGLE {pitch} {yaw}"
    return send_command(command)

def setup_mpc():
    m = GEKKO()
    
    # Define time points
    m.time = np.linspace(0, 2, 21)  # 2 seconds, 21 points
    
    # Define variables
    pitch_measured = m.CV(value=0)    # Controlled Variable (measured pitch)
    servo_angle = m.MV(value=90)      # Manipulated Variable (servo angle)
    
    # MV properties
    servo_angle.LOWER = 0
    servo_angle.UPPER = 180
    servo_angle.DMAX = 10             # Maximum change per time step
    servo_angle.STATUS = 1            # Enable optimization
    
    # CV properties
    pitch_measured.STATUS = 1         # Include in objective function
    
    # Simple first-order dynamic model
    # dpitch/dt = K * (servo_angle - pitch)
    K = 0.8  # Process gain
    tau = 0.5  # Time constant
    m.Equation(tau * pitch_measured.dt() == -pitch_measured + K * servo_angle)
    
    # Configure MPC
    m.options.IMODE = 6    # MPC control
    m.options.CV_TYPE = 2  # Squared error objective
    m.options.NODES = 3    # Collocation nodes
    
    return m, pitch_measured, servo_angle

def correct_pitch_mpc(target_pitch, actual_pitch, current_servo_pitch):
    # Initialize or get existing MPC
    if not hasattr(correct_pitch_mpc, 'mpc'):
        correct_pitch_mpc.mpc, correct_pitch_mpc.pitch_cv, correct_pitch_mpc.servo_mv = setup_mpc()
    
    m = correct_pitch_mpc.mpc
    pitch_cv = correct_pitch_mpc.pitch_cv
    servo_mv = correct_pitch_mpc.servo_mv
    
    # Update current state and setpoint
    pitch_cv.MEAS = actual_pitch
    pitch_cv.SP = target_pitch
    
    # Solve MPC
    try:
        m.solve(disp=False)
        # Get first control move
        new_servo_pitch = float(servo_mv.NEWVAL)
        # Ensure angles stay within 0-180 range
        new_servo_pitch = max(0, min(180, new_servo_pitch))
        return new_servo_pitch
    except:
        print("MPC solution failed, using current angle")
        return current_servo_pitch

try:
    # Clear initial buffer
    time.sleep(2)
    ser.reset_input_buffer()
    
    # Use sample.csv file
    csv_path = "sample.csv"
    
    # Read angles from CSV
    with open(csv_path, 'r') as file:
        csv_reader = csv.DictReader(file)
        
        for row in csv_reader:
            # Get target angles from CSV
            target_pitch = float(row['pitch'])
            target_yaw = float(row['yaw'])
            
            # Ensure angles stay within 0-180 range
            target_pitch = max(0, min(180, target_pitch))
            target_yaw = max(0, min(180, target_yaw))
            
            # Initialize current servo pitch
            current_servo_pitch = target_pitch
            
            # Send angles and get actual readings
            actual_angles = send_angles(current_servo_pitch, target_yaw)
            
            if actual_angles:
                actual_pitch, actual_yaw = actual_angles
                pitch_error = abs(target_pitch - actual_pitch)
                yaw_error = abs(target_yaw - actual_yaw)
                
                # Store results
                results.append({
                    'Target Pitch': target_pitch,
                    'Actual Pitch': actual_pitch,
                    'Error': pitch_error
                })
                
                print(f"Target angles - Pitch: {target_pitch:.2f}, Yaw: {target_yaw:.2f}")
                print(f"Actual angles - Pitch: {actual_pitch:.2f}, Yaw: {actual_yaw:.2f}")
                print(f"Errors - Pitch: {pitch_error:.2f}, Yaw: {yaw_error:.2f}")
                
                # Calculate corrected pitch angle using MPC
                current_servo_pitch = correct_pitch_mpc(target_pitch, actual_pitch, current_servo_pitch)
                print(f"Corrected servo pitch: {current_servo_pitch:.2f}")
            
            # Small delay between movements
            time.sleep(0.05)

except KeyboardInterrupt:
    # Save results to CSV on keyboard interrupt
    with open('results.csv', 'w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=['Target Pitch', 'Actual Pitch', 'Error'])
        writer.writeheader()
        writer.writerows(results)
        print("\nResults saved to results.csv")

finally:
    ser.close()
    print("Serial connection closed")
# Out:
# Pico response: ANGLE 90.0 45.0
# Pico response: Debug: Received 'ANGLE 90.0 45.0'
# Pico response: MPU: 76.62434 42.99139
# Target angles - Pitch: 90.00, Yaw: 45.00
# Actual angles - Pitch: 76.62, Yaw: 42.99
# Errors - Pitch: 13.38, Yaw: 2.01
# Corrected servo pitch: 100.00
# Pico response: ANGLE 88.42951 45.02741
# Pico response: Debug: Received 'ANGLE 88.42951 45.02741'
# Pico response: MPU: 70.1647 34.37241
# Target angles - Pitch: 88.43, Yaw: 45.03
# Actual angles - Pitch: 70.16, Yaw: 34.37
# Errors - Pitch: 18.26, Yaw: 10.66
# Corrected servo pitch: 100.00
# Pico response: ANGLE 86.86096 45.10961
# Pico response: Debug: Received 'ANGLE 86.86096 45.10961'
# Pico response: MPU: 81.67088 31.74997
# Target angles - Pitch: 86.86, Yaw: 45.11
# Actual angles - Pitch: 81.67, Yaw: 31.75
# Errors - Pitch: 5.19, Yaw: 13.36
# Corrected servo pitch: 100.00
# Pico response: ANGLE 85.29621 45.24651
# Pico response: Debug: Received 'ANGLE 85.29621 45.24651'
# Pico response: MPU: 81.40479 28.93801
# Target angles - Pitch: 85.30, Yaw: 45.25
# Actual angles - Pitch: 81.40, Yaw: 28.94
# Errors - Pitch: 3.89, Yaw: 16.31
# Corrected servo pitch: 100.00
# Pico response: ANGLE 83.73721 45.43794
# Pico response: Debug: Received 'ANGLE 83.73721 45.43794'
# Pico response: MPU: 81.33156 26.32021
# Target angles - Pitch: 83.74, Yaw: 45.44
# Actual angles - Pitch: 81.33, Yaw: 26.32
# Errors - Pitch: 2.41, Yaw: 19.12
# Corrected servo pitch: 100.00
# Pico response: ANGLE 82.18582 45.68365
# Pico response: Debug: Received 'ANGLE 82.18582 45.68365'
# Pico response: MPU: 79.76268 25.01022
# Target angles - Pitch: 82.19, Yaw: 45.68
# Actual angles - Pitch: 79.76, Yaw: 25.01
# Errors - Pitch: 2.42, Yaw: 20.67
# Corrected servo pitch: 100.00
# Pico response: ANGLE 80.64396 45.98336
# Pico response: Debug: Received 'ANGLE 80.64396 45.98336'
# Pico response: MPU: 77.22555 22.77169
# Target angles - Pitch: 80.64, Yaw: 45.98
# Actual angles - Pitch: 77.23, Yaw: 22.77
# Errors - Pitch: 3.42, Yaw: 23.21
# Corrected servo pitch: 100.00
# Pico response: ANGLE 79.11351 46.33669
# Pico response: Debug: Received 'ANGLE 79.11351 46.33669'
# Pico response: MPU: 76.34776 20.62284
# Target angles - Pitch: 79.11, Yaw: 46.34
# Actual angles - Pitch: 76.35, Yaw: 20.62
# Errors - Pitch: 2.77, Yaw: 25.71
# Corrected servo pitch: 100.00
# Pico response: ANGLE 77.59631 46.74322
# Pico response: Debug: Received 'ANGLE 77.59631 46.74322'
# Pico response: MPU: 80.05963 18.40089
# Target angles - Pitch: 77.60, Yaw: 46.74
# Actual angles - Pitch: 80.06, Yaw: 18.40
# Errors - Pitch: 2.46, Yaw: 28.34
# Corrected servo pitch: 100.00
# Pico response: ANGLE 76.09425 47.20247
# Pico response: Debug: Received 'ANGLE 76.09425 47.20247'
# Pico response: MPU: 78.96026 16.36506
# Target angles - Pitch: 76.09, Yaw: 47.20
# Actual angles - Pitch: 78.96, Yaw: 16.37
# Errors - Pitch: 2.87, Yaw: 30.84
# Corrected servo pitch: 100.00
# Pico response: ANGLE 74.60909 47.71383
# Pico response: Debug: Received 'ANGLE 74.60909 47.71383'
# Pico response: MPU: 73.58749 15.6387
# Target angles - Pitch: 74.61, Yaw: 47.71
# Actual angles - Pitch: 73.59, Yaw: 15.64
# Errors - Pitch: 1.02, Yaw: 32.08
# Corrected servo pitch: 100.00
# Pico response: ANGLE 73.1427 48.27673
# Pico response: Debug: Received 'ANGLE 73.1427 48.27673'
# Pico response: MPU: 73.349 14.50418
# Target angles - Pitch: 73.14, Yaw: 48.28
# Actual angles - Pitch: 73.35, Yaw: 14.50
# Errors - Pitch: 0.21, Yaw: 33.77
# Corrected servo pitch: 100.00
# Pico response: ANGLE 71.69685 48.89045
# Pico response: Debug: Received 'ANGLE 71.69685 48.89045'
# Pico response: MPU: 81.97919 11.15688
# Target angles - Pitch: 71.70, Yaw: 48.89
# Actual angles - Pitch: 81.98, Yaw: 11.16
# Errors - Pitch: 10.28, Yaw: 37.73
# Corrected servo pitch: 100.00
# Pico response: ANGLE 70.27328 49.55426
# Pico response: Debug: Received 'ANGLE 70.27328 49.55426'
# Pico response: MPU: 74.73114 7.868178
# Target angles - Pitch: 70.27, Yaw: 49.55
# Actual angles - Pitch: 74.73, Yaw: 7.87
# Errors - Pitch: 4.46, Yaw: 41.69
# Corrected servo pitch: 99.71
# Pico response: ANGLE 68.87378 50.26736
# Pico response: Debug: Received 'ANGLE 68.87378 50.26736'
# Pico response: MPU: 68.24886 6.629318
# Target angles - Pitch: 68.87, Yaw: 50.27
# Actual angles - Pitch: 68.25, Yaw: 6.63
# Errors - Pitch: 0.62, Yaw: 43.64
# Corrected servo pitch: 87.14
# Pico response: ANGLE 67.5 51.02886
# Pico response: Debug: Received 'ANGLE 67.5 51.02886'
# Pico response: MPU: 68.48591 5.721393
# Target angles - Pitch: 67.50, Yaw: 51.03
# Actual angles - Pitch: 68.49, Yaw: 5.72
# Errors - Pitch: 0.99, Yaw: 45.31
# Corrected servo pitch: 80.00
# Pico response: ANGLE 66.15363 51.83783
# Pico response: Debug: Received 'ANGLE 66.15363 51.83783'
# Pico response: MPU: 73.57637 3.626139
# Target angles - Pitch: 66.15, Yaw: 51.84
# Actual angles - Pitch: 73.58, Yaw: 3.63
# Errors - Pitch: 7.42, Yaw: 48.21
# Corrected servo pitch: 80.00
# Pico response: ANGLE 64.83633 52.69331
# Pico response: Debug: Received 'ANGLE 64.83633 52.69331'
# Pico response: MPU: 64.80621 2.05251
# Target angles - Pitch: 64.84, Yaw: 52.69
# Actual angles - Pitch: 64.81, Yaw: 2.05
# Errors - Pitch: 0.03, Yaw: 50.64
# Corrected servo pitch: 80.00
# Pico response: ANGLE 63.54967 53.59423
# Pico response: Debug: Received 'ANGLE 63.54967 53.59423'
# Pico response: MPU: 71.03863 0.933146
# Target angles - Pitch: 63.55, Yaw: 53.59
# Actual angles - Pitch: 71.04, Yaw: 0.93
# Errors - Pitch: 7.49, Yaw: 52.66
# Corrected servo pitch: 80.00
# Pico response: ANGLE 62.29523 54.53952
# Pico response: Debug: Received 'ANGLE 62.29523 54.53952'
# Pico response: MPU: 63.60786 0.02417529
# Target angles - Pitch: 62.30, Yaw: 54.54
# Actual angles - Pitch: 63.61, Yaw: 0.02
# Errors - Pitch: 1.31, Yaw: 54.52
# Corrected servo pitch: 80.00
# Pico response: ANGLE 61.07456 55.52799
# Pico response: Debug: Received 'ANGLE 61.07456 55.52799'
# Pico response: MPU: 63.99779 179.0986
# Target angles - Pitch: 61.07, Yaw: 55.53
# Actual angles - Pitch: 64.00, Yaw: 179.10
# Errors - Pitch: 2.92, Yaw: 123.57
# Corrected servo pitch: 80.00
# Pico response: ANGLE 59.88913 56.55848
# Pico response: Debug: Received 'ANGLE 59.88913 56.55848'
# Pico response: MPU: 61.1407 178.2176
# Target angles - Pitch: 59.89, Yaw: 56.56
# Actual angles - Pitch: 61.14, Yaw: 178.22
# Errors - Pitch: 1.25, Yaw: 121.66
# Corrected servo pitch: 80.00
# Pico response: ANGLE 58.74037 57.6297
# Pico response: Debug: Received 'ANGLE 58.74037 57.6297'
# Pico response: MPU: 66.32664 177.0347
# Target angles - Pitch: 58.74, Yaw: 57.63
# Actual angles - Pitch: 66.33, Yaw: 177.03
# Errors - Pitch: 7.59, Yaw: 119.40
# Corrected servo pitch: 80.00
# Pico response: ANGLE 57.6297 58.74037
# Pico response: Debug: Received 'ANGLE 57.6297 58.74037'
# Pico response: MPU: 63.93429 175.7604
# Target angles - Pitch: 57.63, Yaw: 58.74
# Actual angles - Pitch: 63.93, Yaw: 175.76
# Errors - Pitch: 6.30, Yaw: 117.02
# Corrected servo pitch: 80.00
# Pico response: ANGLE 56.55848 59.88913
# Pico response: Debug: Received 'ANGLE 56.55848 59.88913'
# Pico response: MPU: 64.22207 173.7747
# Target angles - Pitch: 56.56, Yaw: 59.89
# Actual angles - Pitch: 64.22, Yaw: 173.77
# Errors - Pitch: 7.66, Yaw: 113.89
# Corrected servo pitch: 80.00
# Pico response: ANGLE 55.528 61.07457
# Pico response: Debug: Received 'ANGLE 55.528 61.07457'
# Pico response: MPU: 59.96411 174.3036
# Target angles - Pitch: 55.53, Yaw: 61.07
# Actual angles - Pitch: 59.96, Yaw: 174.30
# Errors - Pitch: 4.44, Yaw: 113.23
# Corrected servo pitch: 80.00
# Pico response: ANGLE 54.53952 62.29523
# Pico response: Debug: Received 'ANGLE 54.53952 62.29523'
# Pico response: MPU: 62.20483 173.8195
# Target angles - Pitch: 54.54, Yaw: 62.30
# Actual angles - Pitch: 62.20, Yaw: 173.82
# Errors - Pitch: 7.67, Yaw: 111.52
# Corrected servo pitch: 80.00
# Pico response: ANGLE 53.59423 63.54966
# Pico response: Debug: Received 'ANGLE 53.59423 63.54966'
# Pico response: MPU: 58.02876 172.3592
# Target angles - Pitch: 53.59, Yaw: 63.55
# Actual angles - Pitch: 58.03, Yaw: 172.36
# Errors - Pitch: 4.43, Yaw: 108.81
# Corrected servo pitch: 80.00
# Pico response: ANGLE 52.69331 64.83633
# Pico response: Debug: Received 'ANGLE 52.69331 64.83633'
# Pico response: MPU: 57.11491 172.3271
# Target angles - Pitch: 52.69, Yaw: 64.84
# Actual angles - Pitch: 57.11, Yaw: 172.33
# Errors - Pitch: 4.42, Yaw: 107.49
# Corrected servo pitch: 80.00
# Pico response: ANGLE 51.83783 66.15363
# Pico response: Debug: Received 'ANGLE 51.83783 66.15363'
# Pico response: MPU: 48.59193 177.0517
# Target angles - Pitch: 51.84, Yaw: 66.15
# Actual angles - Pitch: 48.59, Yaw: 177.05
# Errors - Pitch: 3.25, Yaw: 110.90
# Corrected servo pitch: 80.00
# Pico response: ANGLE 51.02886 67.49998
# Pico response: Debug: Received 'ANGLE 51.02886 67.49998'
# Pico response: MPU: 55.59337 177.5305
# Target angles - Pitch: 51.03, Yaw: 67.50
# Actual angles - Pitch: 55.59, Yaw: 177.53
# Errors - Pitch: 4.56, Yaw: 110.03
# Corrected servo pitch: 80.00
# Pico response: ANGLE 50.26736 68.87378
# Pico response: Debug: Received 'ANGLE 50.26736 68.87378'
# Pico response: MPU: 54.1996 176.3808
# Target angles - Pitch: 50.27, Yaw: 68.87
# Actual angles - Pitch: 54.20, Yaw: 176.38
# Errors - Pitch: 3.93, Yaw: 107.51
# Corrected servo pitch: 80.00
# Pico response: ANGLE 49.55426 70.27328
# Pico response: Debug: Received 'ANGLE 49.55426 70.27328'
# Pico response: MPU: 53.0967 177.437
# Target angles - Pitch: 49.55, Yaw: 70.27
# Actual angles - Pitch: 53.10, Yaw: 177.44
# Errors - Pitch: 3.54, Yaw: 107.16
# Corrected servo pitch: 80.00
# Pico response: ANGLE 48.89045 71.69685
# Pico response: Debug: Received 'ANGLE 48.89045 71.69685'
# Pico response: MPU: 51.84554 176.421
# Target angles - Pitch: 48.89, Yaw: 71.70
# Actual angles - Pitch: 51.85, Yaw: 176.42
# Errors - Pitch: 2.96, Yaw: 104.72
# Corrected servo pitch: 80.00
# Pico response: ANGLE 48.27673 73.1427
# Pico response: Debug: Received 'ANGLE 48.27673 73.1427'
# Pico response: MPU: 48.67439 178.7746
# Target angles - Pitch: 48.28, Yaw: 73.14
# Actual angles - Pitch: 48.67, Yaw: 178.77
# Errors - Pitch: 0.40, Yaw: 105.63
# Corrected servo pitch: 80.00
# Pico response: ANGLE 47.71383 74.60909
# Pico response: Debug: Received 'ANGLE 47.71383 74.60909'
# Pico response: MPU: 53.34056 178.1461
# Target angles - Pitch: 47.71, Yaw: 74.61
# Actual angles - Pitch: 53.34, Yaw: 178.15
# Errors - Pitch: 5.63, Yaw: 103.54
# Corrected servo pitch: 80.00
# Pico response: ANGLE 47.20246 76.09425
# Pico response: Debug: Received 'ANGLE 47.20246 76.09425'
# Pico response: MPU: 45.3705 177.7304
# Target angles - Pitch: 47.20, Yaw: 76.09
# Actual angles - Pitch: 45.37, Yaw: 177.73
# Errors - Pitch: 1.83, Yaw: 101.64
# Corrected servo pitch: 80.00
# Pico response: ANGLE 46.74322 77.59631
# Pico response: Debug: Received 'ANGLE 46.74322 77.59631'
# Pico response: MPU: 48.46208 177.635
# Target angles - Pitch: 46.74, Yaw: 77.60
# Actual angles - Pitch: 48.46, Yaw: 177.63
# Errors - Pitch: 1.72, Yaw: 100.04
# Corrected servo pitch: 80.00
# Pico response: ANGLE 46.33669 79.11351
# Pico response: Debug: Received 'ANGLE 46.33669 79.11351'
# Pico response: MPU: 44.38844 1.283829
# Target angles - Pitch: 46.34, Yaw: 79.11
# Actual angles - Pitch: 44.39, Yaw: 1.28
# Errors - Pitch: 1.95, Yaw: 77.83
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.98336 80.64396
# Pico response: Debug: Received 'ANGLE 45.98336 80.64396'
# Pico response: MPU: 48.72001 1.716861
# Target angles - Pitch: 45.98, Yaw: 80.64
# Actual angles - Pitch: 48.72, Yaw: 1.72
# Errors - Pitch: 2.74, Yaw: 78.93
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.68365 82.18582
# Pico response: Debug: Received 'ANGLE 45.68365 82.18582'
# Pico response: MPU: 46.57797 2.387139
# Target angles - Pitch: 45.68, Yaw: 82.19
# Actual angles - Pitch: 46.58, Yaw: 2.39
# Errors - Pitch: 0.89, Yaw: 79.80
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.43794 83.73721
# Pico response: Debug: Received 'ANGLE 45.43794 83.73721'
# Pico response: MPU: 49.29654 3.14518
# Target angles - Pitch: 45.44, Yaw: 83.74
# Actual angles - Pitch: 49.30, Yaw: 3.15
# Errors - Pitch: 3.86, Yaw: 80.59
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.24651 85.29621
# Pico response: Debug: Received 'ANGLE 45.24651 85.29621'
# Pico response: MPU: 46.78757 3.243688
# Target angles - Pitch: 45.25, Yaw: 85.30
# Actual angles - Pitch: 46.79, Yaw: 3.24
# Errors - Pitch: 1.54, Yaw: 82.05
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.10961 86.86096
# Pico response: Debug: Received 'ANGLE 45.10961 86.86096'
# Pico response: MPU: 46.23677 3.415824
# Target angles - Pitch: 45.11, Yaw: 86.86
# Actual angles - Pitch: 46.24, Yaw: 3.42
# Errors - Pitch: 1.13, Yaw: 83.45
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.02741 88.42951
# Pico response: Debug: Received 'ANGLE 45.02741 88.42951'
# Pico response: MPU: 46.10633 3.512789
# Target angles - Pitch: 45.03, Yaw: 88.43
# Actual angles - Pitch: 46.11, Yaw: 3.51
# Errors - Pitch: 1.08, Yaw: 84.92
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.0 90.0
# Pico response: Debug: Received 'ANGLE 45.0 90.0'
# Pico response: MPU: 44.31748 3.931591
# Target angles - Pitch: 45.00, Yaw: 90.00
# Actual angles - Pitch: 44.32, Yaw: 3.93
# Errors - Pitch: 0.68, Yaw: 86.07
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.02741 91.57048
# Pico response: Debug: Received 'ANGLE 45.02741 91.57048'
# Pico response: MPU: 46.03526 4.419822
# Target angles - Pitch: 45.03, Yaw: 91.57
# Actual angles - Pitch: 46.04, Yaw: 4.42
# Errors - Pitch: 1.01, Yaw: 87.15
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.10961 93.13904
# Pico response: Debug: Received 'ANGLE 45.10961 93.13904'
# Pico response: MPU: 46.17231 4.582584
# Target angles - Pitch: 45.11, Yaw: 93.14
# Actual angles - Pitch: 46.17, Yaw: 4.58
# Errors - Pitch: 1.06, Yaw: 88.56
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.24651 94.70377
# Pico response: Debug: Received 'ANGLE 45.24651 94.70377'
# Pico response: MPU: 45.95778 4.867862
# Target angles - Pitch: 45.25, Yaw: 94.70
# Actual angles - Pitch: 45.96, Yaw: 4.87
# Errors - Pitch: 0.71, Yaw: 89.84
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.43794 96.26279
# Pico response: Debug: Received 'ANGLE 45.43794 96.26279'
# Pico response: MPU: 46.92762 4.936852
# Target angles - Pitch: 45.44, Yaw: 96.26
# Actual angles - Pitch: 46.93, Yaw: 4.94
# Errors - Pitch: 1.49, Yaw: 91.33
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.68365 97.81417
# Pico response: Debug: Received 'ANGLE 45.68365 97.81417'
# Pico response: MPU: 46.01481 5.236706
# Target angles - Pitch: 45.68, Yaw: 97.81
# Actual angles - Pitch: 46.01, Yaw: 5.24
# Errors - Pitch: 0.33, Yaw: 92.58
# Corrected servo pitch: 80.00
# Pico response: ANGLE 45.98336 99.35603
# Pico response: Debug: Received 'ANGLE 45.98336 99.35603'
# Pico response: MPU: 46.46461 5.287644
# Target angles - Pitch: 45.98, Yaw: 99.36
# Actual angles - Pitch: 46.46, Yaw: 5.29
# Errors - Pitch: 0.48, Yaw: 94.07
# Corrected servo pitch: 80.00
# Pico response: ANGLE 46.33669 100.8865
# Pico response: Debug: Received 'ANGLE 46.33669 100.8865'
# Pico response: MPU: 46.84418 5.454453
# Target angles - Pitch: 46.34, Yaw: 100.89
# Actual angles - Pitch: 46.84, Yaw: 5.45
# Errors - Pitch: 0.51, Yaw: 95.43
# Corrected servo pitch: 80.00
# Pico response: ANGLE 46.74322 102.4037
# Pico response: Debug: Received 'ANGLE 46.74322 102.4037'
# Pico response: MPU: 46.21429 5.370653
# Target angles - Pitch: 46.74, Yaw: 102.40
# Actual angles - Pitch: 46.21, Yaw: 5.37
# Errors - Pitch: 0.53, Yaw: 97.03
# Corrected servo pitch: 80.00
# Pico response: ANGLE 47.20247 103.9058
# Pico response: Debug: Received 'ANGLE 47.20247 103.9058'
# Pico response: MPU: 46.71365 5.730504
# Target angles - Pitch: 47.20, Yaw: 103.91
# Actual angles - Pitch: 46.71, Yaw: 5.73
# Errors - Pitch: 0.49, Yaw: 98.18
# Corrected servo pitch: 80.00
# Pico response: ANGLE 47.71383 105.3909
# Pico response: Debug: Received 'ANGLE 47.71383 105.3909'
# Pico response: MPU: 46.72481 5.7391
# Target angles - Pitch: 47.71, Yaw: 105.39
# Actual angles - Pitch: 46.72, Yaw: 5.74
# Errors - Pitch: 0.99, Yaw: 99.65
# Corrected servo pitch: 80.00
# Pico response: ANGLE 48.27673 106.8573
# Pico response: Debug: Received 'ANGLE 48.27673 106.8573'
# Pico response: MPU: 47.3166 5.622809
# Target angles - Pitch: 48.28, Yaw: 106.86
# Actual angles - Pitch: 47.32, Yaw: 5.62
# Errors - Pitch: 0.96, Yaw: 101.23
# Corrected servo pitch: 80.00
# Pico response: ANGLE 48.89045 108.3031
# Pico response: Debug: Received 'ANGLE 48.89045 108.3031'
# Pico response: MPU: 46.78051 4.574222
# Target angles - Pitch: 48.89, Yaw: 108.30
# Actual angles - Pitch: 46.78, Yaw: 4.57
# Errors - Pitch: 2.11, Yaw: 103.73
# Corrected servo pitch: 80.00
# Pico response: ANGLE 49.55426 109.7267
# Pico response: Debug: Received 'ANGLE 49.55426 109.7267'
# Pico response: MPU: 49.33601 4.592484
# Target angles - Pitch: 49.55, Yaw: 109.73
# Actual angles - Pitch: 49.34, Yaw: 4.59
# Errors - Pitch: 0.22, Yaw: 105.13
# Corrected servo pitch: 80.00
# Pico response: ANGLE 50.26736 111.1262
# Pico response: Debug: Received 'ANGLE 50.26736 111.1262'
# Pico response: MPU: 50.2291 5.036344
# Target angles - Pitch: 50.27, Yaw: 111.13
# Actual angles - Pitch: 50.23, Yaw: 5.04
# Errors - Pitch: 0.04, Yaw: 106.09
# Corrected servo pitch: 80.00
# Pico response: ANGLE 51.02886 112.5
# Pico response: Debug: Received 'ANGLE 51.02886 112.5'
# Pico response: MPU: 50.40858 4.612244
# Target angles - Pitch: 51.03, Yaw: 112.50
# Actual angles - Pitch: 50.41, Yaw: 4.61
# Errors - Pitch: 0.62, Yaw: 107.89
# Corrected servo pitch: 80.00
# Pico response: ANGLE 51.83783 113.8464
# Pico response: Debug: Received 'ANGLE 51.83783 113.8464'
# Pico response: MPU: 50.84835 4.433754
# Target angles - Pitch: 51.84, Yaw: 113.85
# Actual angles - Pitch: 50.85, Yaw: 4.43
# Errors - Pitch: 0.99, Yaw: 109.41
# Corrected servo pitch: 80.00
# Pico response: ANGLE 52.69331 115.1637
# Pico response: Debug: Received 'ANGLE 52.69331 115.1637'
# Pico response: MPU: 51.39625 4.029198
# Target angles - Pitch: 52.69, Yaw: 115.16
# Actual angles - Pitch: 51.40, Yaw: 4.03
# Errors - Pitch: 1.30, Yaw: 111.13
# Corrected servo pitch: 80.00
#
# Results saved to results.csv
# Serial connection closed

# %%
 Include a sensitivity analysis to show the steady state and dynamic relationships between the manipulated variables and the controlled variables. Show simulated control and optimization results that achieve a best objective. For this third phase of the project, it is not necessary to show the estimator and controller working together. Uncorrupted data and full state feedback (all states assumed to be measured) are acceptable for this progress report. The progress report should be a draft section of the final report that includes control and optimization results and discussion.

# %%
import serial
import time
import math
import csv
from gekko import GEKKO
import numpy as np
import matplotlib.pyplot as plt

ser = serial.Serial(
    port='COM6',
    baudrate=115200,
    timeout=1
)

# List to store results for each run
results = {i: [] for i in range(1, 55)}  # Initialize results dict for 54 runs

def send_command(command):
    ser.reset_input_buffer()
    ser.write(f"{command}\r\n".encode())
    time.sleep(0.01)
    
    while ser.in_waiting:
        response = ser.readline().decode().strip()
        if response:
            print(f"Pico response: {response}")
            if response.startswith("MPU:"):
                return [float(x) for x in response[4:].split()]
    return None

def send_angles(pitch, yaw):
    command = f"ANGLE {pitch} {yaw}"
    return send_command(command)

def setup_mpc():
    m = GEKKO()
    m.time = np.linspace(0, 2, 21)
    
    yaw_measured = m.CV(value=0)
    servo_angle = m.MV(value=90)
    
    servo_angle.LOWER = 0
    servo_angle.UPPER = 180
    servo_angle.DMAX = 10
    servo_angle.STATUS = 1
    
    yaw_measured.STATUS = 1
    
    K = 0.8
    tau = 0.5
    m.Equation(tau * yaw_measured.dt() == -yaw_measured + K * servo_angle)
    
    m.options.IMODE = 6
    m.options.CV_TYPE = 2
    m.options.NODES = 3
    
    return m, yaw_measured, servo_angle

def correct_yaw_mpc(target_yaw, actual_yaw, current_servo_yaw):
    if not hasattr(correct_yaw_mpc, 'mpc'):
        correct_yaw_mpc.mpc, correct_yaw_mpc.yaw_cv, correct_yaw_mpc.servo_mv = setup_mpc()
    
    m = correct_yaw_mpc.mpc
    yaw_cv = correct_yaw_mpc.yaw_cv
    servo_mv = correct_yaw_mpc.servo_mv
    
    yaw_cv.MEAS = actual_yaw
    yaw_cv.SP = target_yaw
    
    try:
        m.solve(disp=False)
        new_servo_yaw = float(servo_mv.NEWVAL)
        new_servo_yaw = max(0, min(180, new_servo_yaw))
        return new_servo_yaw
    except:
        print("MPC solution failed, using current angle")
        return current_servo_yaw

try:
    time.sleep(0.01)
    ser.reset_input_buffer()
    
    # Read from angle_tracking_all_hr.csv
    with open('angle_tracking_all_hr.csv', 'r') as file:
        csv_reader = csv.DictReader(file)
        
        # Process each run (1-54)
        for run in range(1, 55):
            command_count = 0
            pitch_col = f'pitch_{run}'
            yaw_col = f'yaw_{run}'
            
            # Reset file pointer for each run
            file.seek(0)
            next(csv_reader)  # Skip header
            
            for row in csv_reader:
                # Check if we've hit command limit or NaN
                if command_count >= 113 or row[pitch_col] == 'NaN' or row[yaw_col] == 'NaN':
                    break
                    
                target_pitch = float(row[pitch_col])
                target_yaw = float(row[yaw_col])
                
                # Ensure angles stay within bounds
                target_pitch = max(0, min(180, target_pitch))
                target_yaw = max(0, min(180, target_yaw))
                
                current_servo_yaw = target_yaw
                actual_angles = send_angles(target_pitch, current_servo_yaw)
                
                if actual_angles:
                    actual_pitch, actual_yaw = actual_angles
                    pitch_error = abs(target_pitch - actual_pitch)
                    yaw_error = abs(target_yaw - actual_yaw)
                    
                    # Store results for this run
                    results[run].append({
                        f'pitch_{run}': target_pitch,
                        f'measured_pitch_{run}': actual_pitch,
                        f'err_{run}': pitch_error,
                        f'yaw_{run}': target_yaw,
                        f'measured_yaw_{run}': actual_yaw,
                        f'yaw_err_{run}': yaw_error
                    })
                    
                    print(f"Run {run} - Command {command_count + 1}")
                    print(f"Target angles - Pitch: {target_pitch:.2f}, Yaw: {target_yaw:.2f}")
                    print(f"Actual angles - Pitch: {actual_pitch:.2f}, Yaw: {actual_yaw:.2f}")
                    print(f"Errors - Pitch: {pitch_error:.2f}, Yaw: {yaw_error:.2f}")
                    
                    current_servo_yaw = correct_yaw_mpc(target_yaw, actual_yaw, current_servo_yaw)
                    print(f"Corrected servo yaw: {current_servo_yaw:.2f}\n")
                
                command_count += 1
                time.sleep(0.01)

except KeyboardInterrupt:
    print("\nOperation interrupted by user")

finally:
    # Save all results to a single CSV
    all_data = []
    max_rows = 0
    
    # First find the maximum number of rows across all runs
    for run in range(1, 55):
        if results[run]:
            max_rows = max(max_rows, len(results[run]))
    
    # Create the combined data
    for i in range(max_rows):
        row_data = {}
        for run in range(1, 55):
            if results[run] and i < len(results[run]):
                row_data.update(results[run][i])
        all_data.append(row_data)
    
    if all_data:
        filename = 'combined_results.csv'
        fieldnames = []
        for run in range(1, 55):
            if results[run]:
                fieldnames.extend(list(results[run][0].keys()))
        
        with open(filename, 'w', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(all_data)
            print(f"All results saved to {filename}")
    
    ser.close()
    print("Serial connection closed")
# Out:
# Pico response: ANGLE 20.15213678 10.98429288
# Pico response: Debug: Received 'ANGLE 20.15213678 10.98429288'
# Pico response: MPU: 14.34869 154.7639
# Run 1 - Command 1
# Target angles - Pitch: 20.15, Yaw: 10.98
# Actual angles - Pitch: 14.35, Yaw: 154.76
# Errors - Pitch: 5.80, Yaw: 143.78
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.00817339 18.46096319
# Pico response: Debug: Received 'ANGLE 21.00817339 18.46096319'
# Pico response: MPU: 22.50475 156.3179
# Run 1 - Command 2
# Target angles - Pitch: 21.01, Yaw: 18.46
# Actual angles - Pitch: 22.50, Yaw: 156.32
# Errors - Pitch: 1.50, Yaw: 137.86
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.57933061 22.0543713
# Pico response: Debug: Received 'ANGLE 22.57933061 22.0543713'
# Pico response: MPU: 22.40098 155.544
# Run 1 - Command 3
# Target angles - Pitch: 22.58, Yaw: 22.05
# Actual angles - Pitch: 22.40, Yaw: 155.54
# Errors - Pitch: 0.18, Yaw: 133.49
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 24.25072307 24.21719581
# Pico response: Debug: Received 'ANGLE 24.25072307 24.21719581'
# Pico response: MPU: 27.68039 153.7819
# Run 1 - Command 4
# Target angles - Pitch: 24.25, Yaw: 24.22
# Actual angles - Pitch: 27.68, Yaw: 153.78
# Errors - Pitch: 3.43, Yaw: 129.56
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 25.88633141 25.69143774
# Pico response: Debug: Received 'ANGLE 25.88633141 25.69143774'
# Pico response: MPU: 26.17497 155.003
# Run 1 - Command 5
# Target angles - Pitch: 25.89, Yaw: 25.69
# Actual angles - Pitch: 26.17, Yaw: 155.00
# Errors - Pitch: 0.29, Yaw: 129.31
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.01491621 26.77842398
# Pico response: Debug: Received 'ANGLE 27.01491621 26.77842398'
# Pico response: MPU: 27.94462 156.2234
# Run 1 - Command 6
# Target angles - Pitch: 27.01, Yaw: 26.78
# Actual angles - Pitch: 27.94, Yaw: 156.22
# Errors - Pitch: 0.93, Yaw: 129.44
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.61092486 27.62443275
# Pico response: Debug: Received 'ANGLE 27.61092486 27.62443275'
# Pico response: MPU: 27.40931 156.7815
# Run 1 - Command 7
# Target angles - Pitch: 27.61, Yaw: 27.62
# Actual angles - Pitch: 27.41, Yaw: 156.78
# Errors - Pitch: 0.20, Yaw: 129.16
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.67355224 28.30936913
# Pico response: Debug: Received 'ANGLE 27.67355224 28.30936913'
# Pico response: MPU: 29.27619 158.2305
# Run 1 - Command 8
# Target angles - Pitch: 27.67, Yaw: 28.31
# Actual angles - Pitch: 29.28, Yaw: 158.23
# Errors - Pitch: 1.60, Yaw: 129.92
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.64103453 28.88070908
# Pico response: Debug: Received 'ANGLE 27.64103453 28.88070908'
# Pico response: MPU: 29.54067 159.3884
# Run 1 - Command 9
# Target angles - Pitch: 27.64, Yaw: 28.88
# Actual angles - Pitch: 29.54, Yaw: 159.39
# Errors - Pitch: 1.90, Yaw: 130.51
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.54033999 29.36849979
# Pico response: Debug: Received 'ANGLE 27.54033999 29.36849979'
# Pico response: MPU: 29.42603 160.6502
# Run 1 - Command 10
# Target angles - Pitch: 27.54, Yaw: 29.37
# Actual angles - Pitch: 29.43, Yaw: 160.65
# Errors - Pitch: 1.89, Yaw: 131.28
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.388971 29.79272022
# Pico response: Debug: Received 'ANGLE 27.388971 29.79272022'
# Pico response: MPU: 28.65381 161.5842
# Run 1 - Command 11
# Target angles - Pitch: 27.39, Yaw: 29.79
# Actual angles - Pitch: 28.65, Yaw: 161.58
# Errors - Pitch: 1.26, Yaw: 131.79
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.19878515 30.16719368
# Pico response: Debug: Received 'ANGLE 27.19878515 30.16719368'
# Pico response: MPU: 29.30147 162.822
# Run 1 - Command 12
# Target angles - Pitch: 27.20, Yaw: 30.17
# Actual angles - Pitch: 29.30, Yaw: 162.82
# Errors - Pitch: 2.10, Yaw: 132.65
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 26.97810161 30.50180326
# Pico response: Debug: Received 'ANGLE 26.97810161 30.50180326'
# Pico response: MPU: 29.79443 164.1691
# Run 1 - Command 13
# Target angles - Pitch: 26.98, Yaw: 30.50
# Actual angles - Pitch: 29.79, Yaw: 164.17
# Errors - Pitch: 2.82, Yaw: 133.67
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 26.73292895 30.80381249
# Pico response: Debug: Received 'ANGLE 26.73292895 30.80381249'
# Pico response: MPU: 29.35538 165.2997
# Run 1 - Command 14
# Target angles - Pitch: 26.73, Yaw: 30.80
# Actual angles - Pitch: 29.36, Yaw: 165.30
# Errors - Pitch: 2.62, Yaw: 134.50
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 26.46771449 31.07868684
# Pico response: Debug: Received 'ANGLE 26.46771449 31.07868684'
# Pico response: MPU: 29.57983 166.4912
# Run 1 - Command 15
# Target angles - Pitch: 26.47, Yaw: 31.08
# Actual angles - Pitch: 29.58, Yaw: 166.49
# Errors - Pitch: 3.11, Yaw: 135.41
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 26.18581965 31.33062341
# Pico response: Debug: Received 'ANGLE 26.18581965 31.33062341'
# Pico response: MPU: 29.45367 167.8511
# Run 1 - Command 16
# Target angles - Pitch: 26.19, Yaw: 31.33
# Actual angles - Pitch: 29.45, Yaw: 167.85
# Errors - Pitch: 3.27, Yaw: 136.52
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 25.88983162 31.56290326
# Pico response: Debug: Received 'ANGLE 25.88983162 31.56290326'
# Pico response: MPU: 29.37089 169.3828
# Run 1 - Command 17
# Target angles - Pitch: 25.89, Yaw: 31.56
# Actual angles - Pitch: 29.37, Yaw: 169.38
# Errors - Pitch: 3.48, Yaw: 137.82
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 25.58177351 31.77813201
# Pico response: Debug: Received 'ANGLE 25.58177351 31.77813201'
# Pico response: MPU: 29.2503 170.5548
# Run 1 - Command 18
# Target angles - Pitch: 25.58, Yaw: 31.78
# Actual angles - Pitch: 29.25, Yaw: 170.55
# Errors - Pitch: 3.67, Yaw: 138.78
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 25.26324974 31.97840806
# Pico response: Debug: Received 'ANGLE 25.26324974 31.97840806'
# Pico response: MPU: 29.41207 171.8981
# Run 1 - Command 19
# Target angles - Pitch: 25.26, Yaw: 31.98
# Actual angles - Pitch: 29.41, Yaw: 171.90
# Errors - Pitch: 4.15, Yaw: 139.92
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 24.93554864 32.16544272
# Pico response: Debug: Received 'ANGLE 24.93554864 32.16544272'
# Pico response: MPU: 29.51705 173.282
# Run 1 - Command 20
# Target angles - Pitch: 24.94, Yaw: 32.17
# Actual angles - Pitch: 29.52, Yaw: 173.28
# Errors - Pitch: 4.58, Yaw: 141.12
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 24.59971651 32.3406475
# Pico response: Debug: Received 'ANGLE 24.59971651 32.3406475'
# Pico response: MPU: 27.95052 174.4792
# Run 1 - Command 21
# Target angles - Pitch: 24.60, Yaw: 32.34
# Actual angles - Pitch: 27.95, Yaw: 174.48
# Errors - Pitch: 3.35, Yaw: 142.14
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 24.25661179 32.5051987
# Pico response: Debug: Received 'ANGLE 24.25661179 32.5051987'
# Pico response: MPU: 27.45179 175.9705
# Run 1 - Command 22
# Target angles - Pitch: 24.26, Yaw: 32.51
# Actual angles - Pitch: 27.45, Yaw: 175.97
# Errors - Pitch: 3.20, Yaw: 143.47
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 23.90694544 32.6600858
# Pico response: Debug: Received 'ANGLE 23.90694544 32.6600858'
# Pico response: MPU: 27.09236 177.4471
# Run 1 - Command 23
# Target angles - Pitch: 23.91, Yaw: 32.66
# Actual angles - Pitch: 27.09, Yaw: 177.45
# Errors - Pitch: 3.19, Yaw: 144.79
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 23.55131144 32.80614837
# Pico response: Debug: Received 'ANGLE 23.55131144 32.80614837'
# Pico response: MPU: 26.62706 179.0249
# Run 1 - Command 24
# Target angles - Pitch: 23.55, Yaw: 32.81
# Actual angles - Pitch: 26.63, Yaw: 179.02
# Errors - Pitch: 3.08, Yaw: 146.22
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 23.19021007 32.94410439
# Pico response: Debug: Received 'ANGLE 23.19021007 32.94410439'
# Pico response: MPU: 27.35689 0.5639648
# Run 1 - Command 25
# Target angles - Pitch: 23.19, Yaw: 32.94
# Actual angles - Pitch: 27.36, Yaw: 0.56
# Errors - Pitch: 4.17, Yaw: 32.38
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.82406598 33.0745724
# Pico response: Debug: Received 'ANGLE 22.82406598 33.0745724'
# Pico response: MPU: 26.34772 2.083437
# Run 1 - Command 26
# Target angles - Pitch: 22.82, Yaw: 33.07
# Actual angles - Pitch: 26.35, Yaw: 2.08
# Errors - Pitch: 3.52, Yaw: 30.99
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.45324224 33.19808892
# Pico response: Debug: Received 'ANGLE 22.45324224 33.19808892'
# Pico response: MPU: 25.69151 3.385327
# Run 1 - Command 27
# Target angles - Pitch: 22.45, Yaw: 33.20
# Actual angles - Pitch: 25.69, Yaw: 3.39
# Errors - Pitch: 3.24, Yaw: 29.81
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.07805151 33.31512225
# Pico response: Debug: Received 'ANGLE 22.07805151 33.31512225'
# Pico response: MPU: 25.41527 4.912201
# Run 1 - Command 28
# Target angles - Pitch: 22.08, Yaw: 33.32
# Actual angles - Pitch: 25.42, Yaw: 4.91
# Errors - Pitch: 3.34, Yaw: 28.40
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.69876488 33.42608362
# Pico response: Debug: Received 'ANGLE 21.69876488 33.42608362'
# Pico response: MPU: 25.65963 6.725817
# Run 1 - Command 29
# Target angles - Pitch: 21.70, Yaw: 33.43
# Actual angles - Pitch: 25.66, Yaw: 6.73
# Errors - Pitch: 3.96, Yaw: 26.70
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.315619 33.53133615
# Pico response: Debug: Received 'ANGLE 21.315619 33.53133615'
# Pico response: MPU: 24.94756 8.212825
# Run 1 - Command 30
# Target angles - Pitch: 21.32, Yaw: 33.53
# Actual angles - Pitch: 24.95, Yaw: 8.21
# Errors - Pitch: 3.63, Yaw: 25.32
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.92882186 33.6312022
# Pico response: Debug: Received 'ANGLE 20.92882186 33.6312022'
# Pico response: MPU: 24.0911 10.03045
# Run 1 - Command 31
# Target angles - Pitch: 20.93, Yaw: 33.63
# Actual angles - Pitch: 24.09, Yaw: 10.03
# Errors - Pitch: 3.16, Yaw: 23.60
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.53855743 33.72596937
# Pico response: Debug: Received 'ANGLE 20.53855743 33.72596937'
# Pico response: MPU: 23.39648 11.51615
# Run 1 - Command 32
# Target angles - Pitch: 20.54, Yaw: 33.73
# Actual angles - Pitch: 23.40, Yaw: 11.52
# Errors - Pitch: 2.86, Yaw: 22.21
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.14498955 33.81589551
# Pico response: Debug: Received 'ANGLE 20.14498955 33.81589551'
# Pico response: MPU: 23.69543 13.10653
# Run 1 - Command 33
# Target angles - Pitch: 20.14, Yaw: 33.82
# Actual angles - Pitch: 23.70, Yaw: 13.11
# Errors - Pitch: 3.55, Yaw: 20.71
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 19.74826507 33.90121289
# Pico response: Debug: Received 'ANGLE 19.74826507 33.90121289'
# Pico response: MPU: 23.41243 14.5347
# Run 1 - Command 34
# Target angles - Pitch: 19.75, Yaw: 33.90
# Actual angles - Pitch: 23.41, Yaw: 14.53
# Errors - Pitch: 3.66, Yaw: 19.37
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 19.34851649 33.9821316
# Pico response: Debug: Received 'ANGLE 19.34851649 33.9821316'
# Pico response: MPU: 23.45324 16.20139
# Run 1 - Command 35
# Target angles - Pitch: 19.35, Yaw: 33.98
# Actual angles - Pitch: 23.45, Yaw: 16.20
# Errors - Pitch: 4.10, Yaw: 17.78
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 18.9458641 34.05884257
# Pico response: Debug: Received 'ANGLE 18.9458641 34.05884257'
# Pico response: MPU: 22.16336 15.22363
# Run 1 - Command 36
# Target angles - Pitch: 18.95, Yaw: 34.06
# Actual angles - Pitch: 22.16, Yaw: 15.22
# Errors - Pitch: 3.22, Yaw: 18.84
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 18.54041784 34.13151999
# Pico response: Debug: Received 'ANGLE 18.54041784 34.13151999'
# Pico response: MPU: 22.72736 16.84169
# Run 1 - Command 37
# Target angles - Pitch: 18.54, Yaw: 34.13
# Actual angles - Pitch: 22.73, Yaw: 16.84
# Errors - Pitch: 4.19, Yaw: 17.29
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 18.13227881 34.20032344
# Pico response: Debug: Received 'ANGLE 18.13227881 34.20032344'
# Pico response: MPU: 21.93424 18.46701
# Run 1 - Command 38
# Target angles - Pitch: 18.13, Yaw: 34.20
# Actual angles - Pitch: 21.93, Yaw: 18.47
# Errors - Pitch: 3.80, Yaw: 15.73
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 17.72154053 34.26539968
# Pico response: Debug: Received 'ANGLE 17.72154053 34.26539968'
# Pico response: MPU: 22.35364 20.41301
# Run 1 - Command 39
# Target angles - Pitch: 17.72, Yaw: 34.27
# Actual angles - Pitch: 22.35, Yaw: 20.41
# Errors - Pitch: 4.63, Yaw: 13.85
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 17.30829005 34.3268842
# Pico response: Debug: Received 'ANGLE 17.30829005 34.3268842'
# Pico response: MPU: 20.68284 22.52633
# Run 1 - Command 40
# Target angles - Pitch: 17.31, Yaw: 34.33
# Actual angles - Pitch: 20.68, Yaw: 22.53
# Errors - Pitch: 3.37, Yaw: 11.80
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 16.8926088 34.38490253
# Pico response: Debug: Received 'ANGLE 16.8926088 34.38490253'
# Pico response: MPU: 20.64953 24.09877
# Run 1 - Command 41
# Target angles - Pitch: 16.89, Yaw: 34.38
# Actual angles - Pitch: 20.65, Yaw: 24.10
# Errors - Pitch: 3.76, Yaw: 10.29
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 16.47457343 34.43957139
# Pico response: Debug: Received 'ANGLE 16.47457343 34.43957139'
# Pico response: MPU: 21.06715 25.86377
# Run 1 - Command 42
# Target angles - Pitch: 16.47, Yaw: 34.44
# Actual angles - Pitch: 21.07, Yaw: 25.86
# Errors - Pitch: 4.59, Yaw: 8.58
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 16.05425642 34.49099965
# Pico response: Debug: Received 'ANGLE 16.05425642 34.49099965'
# Pico response: MPU: 20.65849 27.75385
# Run 1 - Command 43
# Target angles - Pitch: 16.05, Yaw: 34.49
# Actual angles - Pitch: 20.66, Yaw: 27.75
# Errors - Pitch: 4.60, Yaw: 6.74
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.63172662 34.53928921
# Pico response: Debug: Received 'ANGLE 15.63172662 34.53928921'
# Pico response: MPU: 20.4425 29.44945
# Run 1 - Command 44
# Target angles - Pitch: 15.63, Yaw: 34.54
# Actual angles - Pitch: 20.44, Yaw: 29.45
# Errors - Pitch: 4.81, Yaw: 5.09
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.20704978 34.5845357
# Pico response: Debug: Received 'ANGLE 15.20704978 34.5845357'
# Pico response: MPU: 19.6329 31.26085
# Run 1 - Command 45
# Target angles - Pitch: 15.21, Yaw: 34.58
# Actual angles - Pitch: 19.63, Yaw: 31.26
# Errors - Pitch: 4.43, Yaw: 3.32
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.78028888 34.62682912
# Pico response: Debug: Received 'ANGLE 14.78028888 34.62682912'
# Pico response: MPU: 19.76273 33.05001
# Run 1 - Command 46
# Target angles - Pitch: 14.78, Yaw: 34.63
# Actual angles - Pitch: 19.76, Yaw: 33.05
# Errors - Pitch: 4.98, Yaw: 1.58
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.35150453 34.66625439
# Pico response: Debug: Received 'ANGLE 14.35150453 34.66625439'
# Pico response: MPU: 18.5141 35.13564
# Run 1 - Command 47
# Target angles - Pitch: 14.35, Yaw: 34.67
# Actual angles - Pitch: 18.51, Yaw: 35.14
# Errors - Pitch: 4.16, Yaw: 0.47
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.92075526 34.70289182
# Pico response: Debug: Received 'ANGLE 13.92075526 34.70289182'
# Pico response: MPU: 18.601 37.15948
# Run 1 - Command 48
# Target angles - Pitch: 13.92, Yaw: 34.70
# Actual angles - Pitch: 18.60, Yaw: 37.16
# Errors - Pitch: 4.68, Yaw: 2.46
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.48809777 34.73681751
# Pico response: Debug: Received 'ANGLE 13.48809777 34.73681751'
# Pico response: MPU: 18.42644 39.31911
# Run 1 - Command 49
# Target angles - Pitch: 13.49, Yaw: 34.74
# Actual angles - Pitch: 18.43, Yaw: 39.32
# Errors - Pitch: 4.94, Yaw: 4.58
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.05358715 34.76810373
# Pico response: Debug: Received 'ANGLE 13.05358715 34.76810373'
# Pico response: MPU: 18.04752 41.44549
# Run 1 - Command 50
# Target angles - Pitch: 13.05, Yaw: 34.77
# Actual angles - Pitch: 18.05, Yaw: 41.45
# Errors - Pitch: 4.99, Yaw: 6.68
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 12.61727711 34.79681919
# Pico response: Debug: Received 'ANGLE 12.61727711 34.79681919'
# Pico response: MPU: 17.4279 43.63724
# Run 1 - Command 51
# Target angles - Pitch: 12.62, Yaw: 34.80
# Actual angles - Pitch: 17.43, Yaw: 43.64
# Errors - Pitch: 4.81, Yaw: 8.84
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 12.1792201 34.82302932
# Pico response: Debug: Received 'ANGLE 12.1792201 34.82302932'
# Pico response: MPU: 17.32695 45.54838
# Run 1 - Command 52
# Target angles - Pitch: 12.18, Yaw: 34.82
# Actual angles - Pitch: 17.33, Yaw: 45.55
# Errors - Pitch: 5.15, Yaw: 10.73
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.73946756 34.84679649
# Pico response: Debug: Received 'ANGLE 11.73946756 34.84679649'
# Pico response: MPU: 16.502 47.45649
# Run 1 - Command 53
# Target angles - Pitch: 11.74, Yaw: 34.85
# Actual angles - Pitch: 16.50, Yaw: 47.46
# Errors - Pitch: 4.76, Yaw: 12.61
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.29806995 34.86818023
# Pico response: Debug: Received 'ANGLE 11.29806995 34.86818023'
# Pico response: MPU: 16.10409 49.30186
# Run 1 - Command 54
# Target angles - Pitch: 11.30, Yaw: 34.87
# Actual angles - Pitch: 16.10, Yaw: 49.30
# Errors - Pitch: 4.81, Yaw: 14.43
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 10.85507696 34.88723737
# Pico response: Debug: Received 'ANGLE 10.85507696 34.88723737'
# Pico response: MPU: 14.12502 51.07431
# Run 1 - Command 55
# Target angles - Pitch: 10.86, Yaw: 34.89
# Actual angles - Pitch: 14.13, Yaw: 51.07
# Errors - Pitch: 3.27, Yaw: 16.19
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 10.41053761 34.90402222
# Pico response: Debug: Received 'ANGLE 10.41053761 34.90402222'
# Pico response: MPU: 15.63894 53.7198
# Run 1 - Command 56
# Target angles - Pitch: 10.41, Yaw: 34.90
# Actual angles - Pitch: 15.64, Yaw: 53.72
# Errors - Pitch: 5.23, Yaw: 18.82
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.96450033 34.9185867
# Pico response: Debug: Received 'ANGLE 9.96450033 34.9185867'
# Pico response: MPU: 14.58025 56.10749
# Run 1 - Command 57
# Target angles - Pitch: 9.96, Yaw: 34.92
# Actual angles - Pitch: 14.58, Yaw: 56.11
# Errors - Pitch: 4.62, Yaw: 21.19
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.517013073 34.93098043
# Pico response: Debug: Received 'ANGLE 9.517013073 34.93098043'
# Pico response: MPU: 14.12978 58.48071
# Run 1 - Command 58
# Target angles - Pitch: 9.52, Yaw: 34.93
# Actual angles - Pitch: 14.13, Yaw: 58.48
# Errors - Pitch: 4.61, Yaw: 23.55
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.068123416 34.94125085
# Pico response: Debug: Received 'ANGLE 9.068123416 34.94125085'
# Pico response: MPU: 14.17274 60.37135
# Run 1 - Command 59
# Target angles - Pitch: 9.07, Yaw: 34.94
# Actual angles - Pitch: 14.17, Yaw: 60.37
# Errors - Pitch: 5.10, Yaw: 25.43
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 8.617878632 34.94944334
# Pico response: Debug: Received 'ANGLE 8.617878632 34.94944334'
# Pico response: MPU: 13.52723 66.71207
# Run 1 - Command 60
# Target angles - Pitch: 8.62, Yaw: 34.95
# Actual angles - Pitch: 13.53, Yaw: 66.71
# Errors - Pitch: 4.91, Yaw: 31.76
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 8.166325768 34.95560127
# Pico response: Debug: Received 'ANGLE 8.166325768 34.95560127'
# Pico response: MPU: 13.29224 69.41685
# Run 1 - Command 61
# Target angles - Pitch: 8.17, Yaw: 34.96
# Actual angles - Pitch: 13.29, Yaw: 69.42
# Errors - Pitch: 5.13, Yaw: 34.46
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 7.71351172 34.95976607
# Pico response: Debug: Received 'ANGLE 7.71351172 34.95976607'
# Pico response: MPU: 13.85258 71.74814
# Run 1 - Command 62
# Target angles - Pitch: 7.71, Yaw: 34.96
# Actual angles - Pitch: 13.85, Yaw: 71.75
# Errors - Pitch: 6.14, Yaw: 36.79
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 7.259483293 34.96197736
# Pico response: Debug: Received 'ANGLE 7.259483293 34.96197736'
# Pico response: MPU: 12.20702 74.36851
# Run 1 - Command 63
# Target angles - Pitch: 7.26, Yaw: 34.96
# Actual angles - Pitch: 12.21, Yaw: 74.37
# Errors - Pitch: 4.95, Yaw: 39.41
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.804287263 34.96227295
# Pico response: Debug: Received 'ANGLE 6.804287263 34.96227295'
# Pico response: MPU: 11.99327 76.80988
# Run 1 - Command 64
# Target angles - Pitch: 6.80, Yaw: 34.96
# Actual angles - Pitch: 11.99, Yaw: 76.81
# Errors - Pitch: 5.19, Yaw: 41.85
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.347970435 34.96068894
# Pico response: Debug: Received 'ANGLE 6.347970435 34.96068894'
# Pico response: MPU: 11.36347 78.90424
# Run 1 - Command 65
# Target angles - Pitch: 6.35, Yaw: 34.96
# Actual angles - Pitch: 11.36, Yaw: 78.90
# Errors - Pitch: 5.02, Yaw: 43.94
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 5.890579687 34.95725976
# Pico response: Debug: Received 'ANGLE 5.890579687 34.95725976'
# Pico response: MPU: 11.00112 81.32635
# Run 1 - Command 66
# Target angles - Pitch: 5.89, Yaw: 34.96
# Actual angles - Pitch: 11.00, Yaw: 81.33
# Errors - Pitch: 5.11, Yaw: 46.37
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 5.432162015 34.95201826
# Pico response: Debug: Received 'ANGLE 5.432162015 34.95201826'
# Pico response: MPU: 10.86517 83.58768
# Run 1 - Command 67
# Target angles - Pitch: 5.43, Yaw: 34.95
# Actual angles - Pitch: 10.87, Yaw: 83.59
# Errors - Pitch: 5.43, Yaw: 48.64
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.972764575 34.94499574
# Pico response: Debug: Received 'ANGLE 4.972764575 34.94499574'
# Pico response: MPU: 9.676682 85.82786
# Run 1 - Command 68
# Target angles - Pitch: 4.97, Yaw: 34.94
# Actual angles - Pitch: 9.68, Yaw: 85.83
# Errors - Pitch: 4.70, Yaw: 50.88
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.512434718 34.936222
# Pico response: Debug: Received 'ANGLE 4.512434718 34.936222'
# Pico response: MPU: 9.236649 89.42067
# Run 1 - Command 69
# Target angles - Pitch: 4.51, Yaw: 34.94
# Actual angles - Pitch: 9.24, Yaw: 89.42
# Errors - Pitch: 4.72, Yaw: 54.48
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.051220014 34.92572539
# Pico response: Debug: Received 'ANGLE 4.051220014 34.92572539'
# Pico response: MPU: 9.496796 91.43884
# Run 1 - Command 70
# Target angles - Pitch: 4.05, Yaw: 34.93
# Actual angles - Pitch: 9.50, Yaw: 91.44
# Errors - Pitch: 5.45, Yaw: 56.51
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 3.589168283 34.9135329
# Pico response: Debug: Received 'ANGLE 3.589168283 34.9135329'
# Pico response: MPU: 9.63266 94.50736
# Run 1 - Command 71
# Target angles - Pitch: 3.59, Yaw: 34.91
# Actual angles - Pitch: 9.63, Yaw: 94.51
# Errors - Pitch: 6.04, Yaw: 59.59
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 3.126327613 34.89967015
# Pico response: Debug: Received 'ANGLE 3.126327613 34.89967015'
# Pico response: MPU: 9.851616 96.94959
# Run 1 - Command 72
# Target angles - Pitch: 3.13, Yaw: 34.90
# Actual angles - Pitch: 9.85, Yaw: 96.95
# Errors - Pitch: 6.73, Yaw: 62.05
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 2.662746376 34.88416148
# Pico response: Debug: Received 'ANGLE 2.662746376 34.88416148'
# Pico response: MPU: 8.728607 100.9888
# Run 1 - Command 73
# Target angles - Pitch: 2.66, Yaw: 34.88
# Actual angles - Pitch: 8.73, Yaw: 100.99
# Errors - Pitch: 6.07, Yaw: 66.10
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 2.198473241 34.86703
# Pico response: Debug: Received 'ANGLE 2.198473241 34.86703'
# Pico response: MPU: 8.681183 103.45
# Run 1 - Command 74
# Target angles - Pitch: 2.20, Yaw: 34.87
# Actual angles - Pitch: 8.68, Yaw: 103.45
# Errors - Pitch: 6.48, Yaw: 68.58
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.733557181 34.84829759
# Pico response: Debug: Received 'ANGLE 1.733557181 34.84829759'
# Pico response: MPU: 8.41082 105.7828
# Run 1 - Command 75
# Target angles - Pitch: 1.73, Yaw: 34.85
# Actual angles - Pitch: 8.41, Yaw: 105.78
# Errors - Pitch: 6.68, Yaw: 70.93
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.268047478 34.82798502
# Pico response: Debug: Received 'ANGLE 1.268047478 34.82798502'
# Pico response: MPU: 7.303177 108.3524
# Run 1 - Command 76
# Target angles - Pitch: 1.27, Yaw: 34.83
# Actual angles - Pitch: 7.30, Yaw: 108.35
# Errors - Pitch: 6.04, Yaw: 73.52
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.801993721 34.8061119
# Pico response: Debug: Received 'ANGLE 0.801993721 34.8061119'
# Pico response: MPU: 7.59948 110.6016
# Run 1 - Command 77
# Target angles - Pitch: 0.80, Yaw: 34.81
# Actual angles - Pitch: 7.60, Yaw: 110.60
# Errors - Pitch: 6.80, Yaw: 75.80
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.335445807 34.78269682
# Pico response: Debug: Received 'ANGLE 0.335445807 34.78269682'
# Pico response: MPU: 7.168808 112.8017
# Run 1 - Command 78
# Target angles - Pitch: 0.34, Yaw: 34.78
# Actual angles - Pitch: 7.17, Yaw: 112.80
# Errors - Pitch: 6.83, Yaw: 78.02
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.102089474 34.77073235
# Pico response: Debug: Received 'ANGLE 0.102089474 34.77073235'
# Pico response: MPU: 7.918411 114.8962
# Run 1 - Command 79
# Target angles - Pitch: 0.10, Yaw: 34.77
# Actual angles - Pitch: 7.92, Yaw: 114.90
# Errors - Pitch: 7.82, Yaw: 80.13
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 25.63672415 2.52066803
# Pico response: Debug: Received 'ANGLE 25.63672415 2.52066803'
# Pico response: MPU: 7.335915 117.1291
# Run 2 - Command 1
# Target angles - Pitch: 25.64, Yaw: 2.52
# Actual angles - Pitch: 7.34, Yaw: 117.13
# Errors - Pitch: 18.30, Yaw: 114.61
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 24.58121812 3.988620747
# Pico response: Debug: Received 'ANGLE 24.58121812 3.988620747'
# Pico response: MPU: 28.34239 116.4302
# Run 2 - Command 2
# Target angles - Pitch: 24.58, Yaw: 3.99
# Actual angles - Pitch: 28.34, Yaw: 116.43
# Errors - Pitch: 3.76, Yaw: 112.44
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.51586709 6.648860098
# Pico response: Debug: Received 'ANGLE 22.51586709 6.648860098'
# Pico response: MPU: 23.95888 118.4906
# Run 2 - Command 3
# Target angles - Pitch: 22.52, Yaw: 6.65
# Actual angles - Pitch: 23.96, Yaw: 118.49
# Errors - Pitch: 1.44, Yaw: 111.84
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.79815336 7.86757314
# Pico response: Debug: Received 'ANGLE 20.79815336 7.86757314'
# Pico response: MPU: 27.4316 119.685
# Run 2 - Command 4
# Target angles - Pitch: 20.80, Yaw: 7.87
# Actual angles - Pitch: 27.43, Yaw: 119.69
# Errors - Pitch: 6.63, Yaw: 111.82
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 19.09735101 8.639397692
# Pico response: Debug: Received 'ANGLE 19.09735101 8.639397692'
# Pico response: MPU: 24.22311 121.4506
# Run 2 - Command 5
# Target angles - Pitch: 19.10, Yaw: 8.64
# Actual angles - Pitch: 24.22, Yaw: 121.45
# Errors - Pitch: 5.13, Yaw: 112.81
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 17.33723969 9.205735419
# Pico response: Debug: Received 'ANGLE 17.33723969 9.205735419'
# Pico response: MPU: 22.34699 123.2564
# Run 2 - Command 6
# Target angles - Pitch: 17.34, Yaw: 9.21
# Actual angles - Pitch: 22.35, Yaw: 123.26
# Errors - Pitch: 5.01, Yaw: 114.05
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 16.12823801 9.657444139
# Pico response: Debug: Received 'ANGLE 16.12823801 9.657444139'
# Pico response: MPU: 20.95086 124.8649
# Run 2 - Command 7
# Target angles - Pitch: 16.13, Yaw: 9.66
# Actual angles - Pitch: 20.95, Yaw: 124.86
# Errors - Pitch: 4.82, Yaw: 115.21
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.46795877 10.03699715
# Pico response: Debug: Received 'ANGLE 15.46795877 10.03699715'
# Pico response: MPU: 20.12077 126.5446
# Run 2 - Command 8
# Target angles - Pitch: 15.47, Yaw: 10.04
# Actual angles - Pitch: 20.12, Yaw: 126.54
# Errors - Pitch: 4.65, Yaw: 116.51
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.36890139 10.36707747
# Pico response: Debug: Received 'ANGLE 15.36890139 10.36707747'
# Pico response: MPU: 18.98978 128.1715
# Run 2 - Command 9
# Target angles - Pitch: 15.37, Yaw: 10.37
# Actual angles - Pitch: 18.99, Yaw: 128.17
# Errors - Pitch: 3.62, Yaw: 117.80
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.21300769 10.66095663
# Pico response: Debug: Received 'ANGLE 15.21300769 10.66095663'
# Pico response: MPU: 19.49193 129.6503
# Run 2 - Command 10
# Target angles - Pitch: 15.21, Yaw: 10.66
# Actual angles - Pitch: 19.49, Yaw: 129.65
# Errors - Pitch: 4.28, Yaw: 118.99
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.01527185 10.92693595
# Pico response: Debug: Received 'ANGLE 15.01527185 10.92693595'
# Pico response: MPU: 18.93981 131.4839
# Run 2 - Command 11
# Target angles - Pitch: 15.02, Yaw: 10.93
# Actual angles - Pitch: 18.94, Yaw: 131.48
# Errors - Pitch: 3.92, Yaw: 120.56
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.78554353 11.17047964
# Pico response: Debug: Received 'ANGLE 14.78554353 11.17047964'
# Pico response: MPU: 18.78423 133.2139
# Run 2 - Command 12
# Target angles - Pitch: 14.79, Yaw: 11.17
# Actual angles - Pitch: 18.78, Yaw: 133.21
# Errors - Pitch: 4.00, Yaw: 122.04
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.53057955 11.39533164
# Pico response: Debug: Received 'ANGLE 14.53057955 11.39533164'
# Pico response: MPU: 18.67935 134.9054
# Run 2 - Command 13
# Target angles - Pitch: 14.53, Yaw: 11.40
# Actual angles - Pitch: 18.68, Yaw: 134.91
# Errors - Pitch: 4.15, Yaw: 123.51
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.25518567 11.60414116
# Pico response: Debug: Received 'ANGLE 14.25518567 11.60414116'
# Pico response: MPU: 18.76051 136.7265
# Run 2 - Command 14
# Target angles - Pitch: 14.26, Yaw: 11.60
# Actual angles - Pitch: 18.76, Yaw: 136.73
# Errors - Pitch: 4.51, Yaw: 125.12
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.96288783 11.79883274
# Pico response: Debug: Received 'ANGLE 13.96288783 11.79883274'
# Pico response: MPU: 18.85783 138.4201
# Run 2 - Command 15
# Target angles - Pitch: 13.96, Yaw: 11.80
# Actual angles - Pitch: 18.86, Yaw: 138.42
# Errors - Pitch: 4.89, Yaw: 126.62
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.65634537 11.98083541
# Pico response: Debug: Received 'ANGLE 13.65634537 11.98083541'
# Pico response: MPU: 17.93018 140.0777
# Run 2 - Command 16
# Target angles - Pitch: 13.66, Yaw: 11.98
# Actual angles - Pitch: 17.93, Yaw: 140.08
# Errors - Pitch: 4.27, Yaw: 128.10
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.33761516 12.15123025
# Pico response: Debug: Received 'ANGLE 13.33761516 12.15123025'
# Pico response: MPU: 18.0204 142.1482
# Run 2 - Command 17
# Target angles - Pitch: 13.34, Yaw: 12.15
# Actual angles - Pitch: 18.02, Yaw: 142.15
# Errors - Pitch: 4.68, Yaw: 130.00
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.00832608 12.31084877
# Pico response: Debug: Received 'ANGLE 13.00832608 12.31084877'
# Pico response: MPU: 17.3625 143.9646
# Run 2 - Command 18
# Target angles - Pitch: 13.01, Yaw: 12.31
# Actual angles - Pitch: 17.36, Yaw: 143.96
# Errors - Pitch: 4.35, Yaw: 131.65
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 12.6697974 12.46034067
# Pico response: Debug: Received 'ANGLE 12.6697974 12.46034067'
# Pico response: MPU: 16.88403 145.7499
# Run 2 - Command 19
# Target angles - Pitch: 12.67, Yaw: 12.46
# Actual angles - Pitch: 16.88, Yaw: 145.75
# Errors - Pitch: 4.21, Yaw: 133.29
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 12.32312101 12.60022179
# Pico response: Debug: Received 'ANGLE 12.32312101 12.60022179'
# Pico response: MPU: 17.0356 147.5061
# Run 2 - Command 20
# Target angles - Pitch: 12.32, Yaw: 12.60
# Actual angles - Pitch: 17.04, Yaw: 147.51
# Errors - Pitch: 4.71, Yaw: 134.91
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.96921957 12.73090916
# Pico response: Debug: Received 'ANGLE 11.96921957 12.73090916'
# Pico response: MPU: 16.45071 148.4212
# Run 2 - Command 21
# Target angles - Pitch: 11.97, Yaw: 12.73
# Actual angles - Pitch: 16.45, Yaw: 148.42
# Errors - Pitch: 4.48, Yaw: 135.69
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.60888823 12.85274707
# Pico response: Debug: Received 'ANGLE 11.60888823 12.85274707'
# Pico response: MPU: 16.66593 150.5418
# Run 2 - Command 22
# Target angles - Pitch: 11.61, Yaw: 12.85
# Actual angles - Pitch: 16.67, Yaw: 150.54
# Errors - Pitch: 5.06, Yaw: 137.69
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.24282474 12.96602701
# Pico response: Debug: Received 'ANGLE 11.24282474 12.96602701'
# Pico response: MPU: 16.39695 152.2906
# Run 2 - Command 23
# Target angles - Pitch: 11.24, Yaw: 12.97
# Actual angles - Pitch: 16.40, Yaw: 152.29
# Errors - Pitch: 5.15, Yaw: 139.32
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 10.87165135 13.07100312
# Pico response: Debug: Received 'ANGLE 10.87165135 13.07100312'
# Pico response: MPU: 17.03242 154.0886
# Run 2 - Command 24
# Target angles - Pitch: 10.87, Yaw: 13.07
# Actual angles - Pitch: 17.03, Yaw: 154.09
# Errors - Pitch: 6.16, Yaw: 141.02
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 10.49593057 13.16790427
# Pico response: Debug: Received 'ANGLE 10.49593057 13.16790427'
# Pico response: MPU: 15.6818 155.7668
# Run 2 - Command 25
# Target angles - Pitch: 10.50, Yaw: 13.17
# Actual angles - Pitch: 15.68, Yaw: 155.77
# Errors - Pitch: 5.19, Yaw: 142.60
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 10.11617647 13.25694349
# Pico response: Debug: Received 'ANGLE 10.11617647 13.25694349'
# Pico response: MPU: 15.05532 157.8759
# Run 2 - Command 26
# Target angles - Pitch: 10.12, Yaw: 13.26
# Actual angles - Pitch: 15.06, Yaw: 157.88
# Errors - Pitch: 4.94, Yaw: 144.62
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.732862567 13.33832525
# Pico response: Debug: Received 'ANGLE 9.732862567 13.33832525'
# Pico response: MPU: 15.19571 159.6261
# Run 2 - Command 27
# Target angles - Pitch: 9.73, Yaw: 13.34
# Actual angles - Pitch: 15.20, Yaw: 159.63
# Errors - Pitch: 5.46, Yaw: 146.29
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.346427307 13.41225091
# Pico response: Debug: Received 'ANGLE 9.346427307 13.41225091'
# Pico response: MPU: 14.40094 161.5955
# Run 2 - Command 28
# Target angles - Pitch: 9.35, Yaw: 13.41
# Actual angles - Pitch: 14.40, Yaw: 161.60
# Errors - Pitch: 5.05, Yaw: 148.18
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 8.957277634 13.47892261
# Pico response: Debug: Received 'ANGLE 8.957277634 13.47892261'
# Pico response: MPU: 13.59982 163.8153
# Run 2 - Command 29
# Target angles - Pitch: 8.96, Yaw: 13.48
# Actual angles - Pitch: 13.60, Yaw: 163.82
# Errors - Pitch: 4.64, Yaw: 150.34
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 8.565791367 13.53854584
# Pico response: Debug: Received 'ANGLE 8.565791367 13.53854584'
# Pico response: MPU: 13.61379 165.913
# Run 2 - Command 30
# Target angles - Pitch: 8.57, Yaw: 13.54
# Actual angles - Pitch: 13.61, Yaw: 165.91
# Errors - Pitch: 5.05, Yaw: 152.37
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 8.172318695 13.59133087
# Pico response: Debug: Received 'ANGLE 8.172318695 13.59133087'
# Pico response: MPU: 13.2404 168.3202
# Run 2 - Command 31
# Target angles - Pitch: 8.17, Yaw: 13.59
# Actual angles - Pitch: 13.24, Yaw: 168.32
# Errors - Pitch: 5.07, Yaw: 154.73
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 7.777183185 13.63749318
# Pico response: Debug: Received 'ANGLE 7.777183185 13.63749318'
# Pico response: MPU: 12.89989 170.2486
# Run 2 - Command 32
# Target angles - Pitch: 7.78, Yaw: 13.64
# Actual angles - Pitch: 12.90, Yaw: 170.25
# Errors - Pitch: 5.12, Yaw: 156.61
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 7.380682537 13.67725326
# Pico response: Debug: Received 'ANGLE 7.380682537 13.67725326'
# Pico response: MPU: 12.99578 172.3773
# Run 2 - Command 33
# Target angles - Pitch: 7.38, Yaw: 13.68
# Actual angles - Pitch: 13.00, Yaw: 172.38
# Errors - Pitch: 5.62, Yaw: 158.70
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.983089282 13.71083575
# Pico response: Debug: Received 'ANGLE 6.983089282 13.71083575'
# Pico response: MPU: 12.21789 174.8753
# Run 2 - Command 34
# Target angles - Pitch: 6.98, Yaw: 13.71
# Actual angles - Pitch: 12.22, Yaw: 174.88
# Errors - Pitch: 5.23, Yaw: 161.16
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.584651535 13.73846821
# Pico response: Debug: Received 'ANGLE 6.584651535 13.73846821'
# Pico response: MPU: 12.75125 176.7067
# Run 2 - Command 35
# Target angles - Pitch: 6.58, Yaw: 13.74
# Actual angles - Pitch: 12.75, Yaw: 176.71
# Errors - Pitch: 6.17, Yaw: 162.97
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.185593869 13.76037974
# Pico response: Debug: Received 'ANGLE 6.185593869 13.76037974'
# Pico response: MPU: 11.86699 178.6648
# Run 2 - Command 36
# Target angles - Pitch: 6.19, Yaw: 13.76
# Actual angles - Pitch: 11.87, Yaw: 178.66
# Errors - Pitch: 5.68, Yaw: 164.90
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 5.786118353 13.77679946
# Pico response: Debug: Received 'ANGLE 5.786118353 13.77679946'
# Pico response: MPU: 11.84985 1.271469
# Run 2 - Command 37
# Target angles - Pitch: 5.79, Yaw: 13.78
# Actual angles - Pitch: 11.85, Yaw: 1.27
# Errors - Pitch: 6.06, Yaw: 12.51
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 5.386405725 13.78795494
# Pico response: Debug: Received 'ANGLE 5.386405725 13.78795494'
# Pico response: MPU: 11.72978 3.400442
# Run 2 - Command 38
# Target angles - Pitch: 5.39, Yaw: 13.79
# Actual angles - Pitch: 11.73, Yaw: 3.40
# Errors - Pitch: 6.34, Yaw: 10.39
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.986616705 13.79407085
# Pico response: Debug: Received 'ANGLE 4.986616705 13.79407085'
# Pico response: MPU: 10.80956 5.977651
# Run 2 - Command 39
# Target angles - Pitch: 4.99, Yaw: 13.79
# Actual angles - Pitch: 10.81, Yaw: 5.98
# Errors - Pitch: 5.82, Yaw: 7.82
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.586893396 13.79536763
# Pico response: Debug: Received 'ANGLE 4.586893396 13.79536763'
# Pico response: MPU: 10.13224 8.193618
# Run 2 - Command 40
# Target angles - Pitch: 4.59, Yaw: 13.80
# Actual angles - Pitch: 10.13, Yaw: 8.19
# Errors - Pitch: 5.55, Yaw: 5.60
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.187360741 13.79206038
# Pico response: Debug: Received 'ANGLE 4.187360741 13.79206038'
# Pico response: MPU: 9.375656 11.03047
# Run 2 - Command 41
# Target angles - Pitch: 4.19, Yaw: 13.79
# Actual angles - Pitch: 9.38, Yaw: 11.03
# Errors - Pitch: 5.19, Yaw: 2.76
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 3.788128003 13.78435799
# Pico response: Debug: Received 'ANGLE 3.788128003 13.78435799'
# Pico response: MPU: 9.32653 14.17135
# Run 2 - Command 42
# Target angles - Pitch: 3.79, Yaw: 13.78
# Actual angles - Pitch: 9.33, Yaw: 14.17
# Errors - Pitch: 5.54, Yaw: 0.39
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 3.389290236 13.77246234
# Pico response: Debug: Received 'ANGLE 3.389290236 13.77246234'
# Pico response: MPU: 10.20071 16.48765
# Run 2 - Command 43
# Target angles - Pitch: 3.39, Yaw: 13.77
# Actual angles - Pitch: 10.20, Yaw: 16.49
# Errors - Pitch: 6.81, Yaw: 2.72
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 2.990929707 13.75656779
# Pico response: Debug: Received 'ANGLE 2.990929707 13.75656779'
# Pico response: MPU: 9.39064 19.03069
# Run 2 - Command 44
# Target angles - Pitch: 2.99, Yaw: 13.76
# Actual angles - Pitch: 9.39, Yaw: 19.03
# Errors - Pitch: 6.40, Yaw: 5.27
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 2.59311727 13.73686076
# Pico response: Debug: Received 'ANGLE 2.59311727 13.73686076'
# Pico response: MPU: 8.361275 21.27186
# Run 2 - Command 45
# Target angles - Pitch: 2.59, Yaw: 13.74
# Actual angles - Pitch: 8.36, Yaw: 21.27
# Errors - Pitch: 5.77, Yaw: 7.53
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 2.195913648 13.71351951
# Pico response: Debug: Received 'ANGLE 2.195913648 13.71351951'
# Pico response: MPU: 8.467773 23.80083
# Run 2 - Command 46
# Target angles - Pitch: 2.20, Yaw: 13.71
# Actual angles - Pitch: 8.47, Yaw: 23.80
# Errors - Pitch: 6.27, Yaw: 10.09
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.799370645 13.686714
# Pico response: Debug: Received 'ANGLE 1.799370645 13.686714'
# Pico response: MPU: 7.313751 26.40477
# Run 2 - Command 47
# Target angles - Pitch: 1.80, Yaw: 13.69
# Actual angles - Pitch: 7.31, Yaw: 26.40
# Errors - Pitch: 5.51, Yaw: 12.72
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.403532251 13.65660589
# Pico response: Debug: Received 'ANGLE 1.403532251 13.65660589'
# Pico response: MPU: 6.91748 29.07952
# Run 2 - Command 48
# Target angles - Pitch: 1.40, Yaw: 13.66
# Actual angles - Pitch: 6.92, Yaw: 29.08
# Errors - Pitch: 5.51, Yaw: 15.42
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.008435662 13.6233486
# Pico response: Debug: Received 'ANGLE 1.008435662 13.6233486'
# Pico response: MPU: 6.929504 31.30353
# Run 2 - Command 49
# Target angles - Pitch: 1.01, Yaw: 13.62
# Actual angles - Pitch: 6.93, Yaw: 31.30
# Errors - Pitch: 5.92, Yaw: 17.68
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.614112203 13.58708749
# Pico response: Debug: Received 'ANGLE 0.614112203 13.58708749'
# Pico response: MPU: 6.978508 34.34259
# Run 2 - Command 50
# Target angles - Pitch: 0.61, Yaw: 13.59
# Actual angles - Pitch: 6.98, Yaw: 34.34
# Errors - Pitch: 6.36, Yaw: 20.76
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.220588158 13.54796001
# Pico response: Debug: Received 'ANGLE 0.220588158 13.54796001'
# Pico response: MPU: 7.878204 36.97384
# Run 2 - Command 51
# Target angles - Pitch: 0.22, Yaw: 13.55
# Actual angles - Pitch: 7.88, Yaw: 36.97
# Errors - Pitch: 7.66, Yaw: 23.43
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.023959608 13.52791897
# Pico response: Debug: Received 'ANGLE 0.023959608 13.52791897'
# Pico response: MPU: 7.98867 39.79562
# Run 2 - Command 52
# Target angles - Pitch: 0.02, Yaw: 13.53
# Actual angles - Pitch: 7.99, Yaw: 39.80
# Errors - Pitch: 7.96, Yaw: 26.27
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 34.09724651 0
# Pico response: Debug: Received 'ANGLE 34.09724651 0'
# Pico response: MPU: 7.436752 43.18874
# Run 3 - Command 1
# Target angles - Pitch: 34.10, Yaw: 0.00
# Actual angles - Pitch: 7.44, Yaw: 43.19
# Errors - Pitch: 26.66, Yaw: 43.19
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 32.65711455 0
# Pico response: Debug: Received 'ANGLE 32.65711455 0'
# Pico response: MPU: 43.41919 44.49419
# Run 3 - Command 2
# Target angles - Pitch: 32.66, Yaw: 0.00
# Actual angles - Pitch: 43.42, Yaw: 44.49
# Errors - Pitch: 10.76, Yaw: 44.49
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 29.8856825 0
# Pico response: Debug: Received 'ANGLE 29.8856825 0'
# Pico response: MPU: 33.30984 45.07904
# Run 3 - Command 3
# Target angles - Pitch: 29.89, Yaw: 0.00
# Actual angles - Pitch: 33.31, Yaw: 45.08
# Errors - Pitch: 3.42, Yaw: 45.08
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 27.71545055 0
# Pico response: Debug: Received 'ANGLE 27.71545055 0'
# Pico response: MPU: 34.08762 45.96632
# Run 3 - Command 4
# Target angles - Pitch: 27.72, Yaw: 0.00
# Actual angles - Pitch: 34.09, Yaw: 45.97
# Errors - Pitch: 6.37, Yaw: 45.97
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 25.68605789 0
# Pico response: Debug: Received 'ANGLE 25.68605789 0'
# Pico response: MPU: 30.25117 47.09843
# Run 3 - Command 5
# Target angles - Pitch: 25.69, Yaw: 0.00
# Actual angles - Pitch: 30.25, Yaw: 47.10
# Errors - Pitch: 4.57, Yaw: 47.10
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 23.67865618 0
# Pico response: Debug: Received 'ANGLE 23.67865618 0'
# Pico response: MPU: 28.25288 48.51697
# Run 3 - Command 6
# Target angles - Pitch: 23.68, Yaw: 0.00
# Actual angles - Pitch: 28.25, Yaw: 48.52
# Errors - Pitch: 4.57, Yaw: 48.52
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.42846697 0
# Pico response: Debug: Received 'ANGLE 22.42846697 0'
# Pico response: MPU: 26.41363 50.02022
# Run 3 - Command 7
# Target angles - Pitch: 22.43, Yaw: 0.00
# Actual angles - Pitch: 26.41, Yaw: 50.02
# Errors - Pitch: 3.99, Yaw: 50.02
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.89542301 0
# Pico response: Debug: Received 'ANGLE 21.89542301 0'
# Pico response: MPU: 25.2822 51.70516
# Run 3 - Command 8
# Target angles - Pitch: 21.90, Yaw: 0.00
# Actual angles - Pitch: 25.28, Yaw: 51.71
# Errors - Pitch: 3.39, Yaw: 51.71
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.06258762 0
# Pico response: Debug: Received 'ANGLE 22.06258762 0'
# Pico response: MPU: 24.14219 53.35207
# Run 3 - Command 9
# Target angles - Pitch: 22.06, Yaw: 0.00
# Actual angles - Pitch: 24.14, Yaw: 53.35
# Errors - Pitch: 2.08, Yaw: 53.35
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.14497669 0
# Pico response: Debug: Received 'ANGLE 22.14497669 0'
# Pico response: MPU: 24.47306 54.92916
# Run 3 - Command 10
# Target angles - Pitch: 22.14, Yaw: 0.00
# Actual angles - Pitch: 24.47, Yaw: 54.93
# Errors - Pitch: 2.33, Yaw: 54.93
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.16502136 0
# Pico response: Debug: Received 'ANGLE 22.16502136 0'
# Pico response: MPU: 25.04104 56.13637
# Run 3 - Command 11
# Target angles - Pitch: 22.17, Yaw: 0.00
# Actual angles - Pitch: 25.04, Yaw: 56.14
# Errors - Pitch: 2.88, Yaw: 56.14
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.13752014 0
# Pico response: Debug: Received 'ANGLE 22.13752014 0'
# Pico response: MPU: 23.82872 57.73484
# Run 3 - Command 12
# Target angles - Pitch: 22.14, Yaw: 0.00
# Actual angles - Pitch: 23.83, Yaw: 57.73
# Errors - Pitch: 1.69, Yaw: 57.73
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 22.07263896 0
# Pico response: Debug: Received 'ANGLE 22.07263896 0'
# Pico response: MPU: 25.22115 59.35802
# Run 3 - Command 13
# Target angles - Pitch: 22.07, Yaw: 0.00
# Actual angles - Pitch: 25.22, Yaw: 59.36
# Errors - Pitch: 3.15, Yaw: 59.36
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.97759525 0
# Pico response: Debug: Received 'ANGLE 21.97759525 0'
# Pico response: MPU: 24.96392 61.20813
# Run 3 - Command 14
# Target angles - Pitch: 21.98, Yaw: 0.00
# Actual angles - Pitch: 24.96, Yaw: 61.21
# Errors - Pitch: 2.99, Yaw: 61.21
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.85765497 0
# Pico response: Debug: Received 'ANGLE 21.85765497 0'
# Pico response: MPU: 24.51722 62.39828
# Run 3 - Command 15
# Target angles - Pitch: 21.86, Yaw: 0.00
# Actual angles - Pitch: 24.52, Yaw: 62.40
# Errors - Pitch: 2.66, Yaw: 62.40
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.71674919 0
# Pico response: Debug: Received 'ANGLE 21.71674919 0'
# Pico response: MPU: 24.80491 64.09593
# Run 3 - Command 16
# Target angles - Pitch: 21.72, Yaw: 0.00
# Actual angles - Pitch: 24.80, Yaw: 64.10
# Errors - Pitch: 3.09, Yaw: 64.10
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.55786965 0
# Pico response: Debug: Received 'ANGLE 21.55786965 0'
# Pico response: MPU: 23.8356 65.77029
# Run 3 - Command 17
# Target angles - Pitch: 21.56, Yaw: 0.00
# Actual angles - Pitch: 23.84, Yaw: 65.77
# Errors - Pitch: 2.28, Yaw: 65.77
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.38333067 0
# Pico response: Debug: Received 'ANGLE 21.38333067 0'
# Pico response: MPU: 24.20774 67.11071
# Run 3 - Command 18
# Target angles - Pitch: 21.38, Yaw: 0.00
# Actual angles - Pitch: 24.21, Yaw: 67.11
# Errors - Pitch: 2.82, Yaw: 67.11
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 21.19494714 0
# Pico response: Debug: Received 'ANGLE 21.19494714 0'
# Pico response: MPU: 24.72807 68.73505
# Run 3 - Command 19
# Target angles - Pitch: 21.19, Yaw: 0.00
# Actual angles - Pitch: 24.73, Yaw: 68.74
# Errors - Pitch: 3.53, Yaw: 68.74
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.9941585 0
# Pico response: Debug: Received 'ANGLE 20.9941585 0'
# Pico response: MPU: 24.66088 70.34514
# Run 3 - Command 20
# Target angles - Pitch: 20.99, Yaw: 0.00
# Actual angles - Pitch: 24.66, Yaw: 70.35
# Errors - Pitch: 3.67, Yaw: 70.35
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.78211657 0
# Pico response: Debug: Received 'ANGLE 20.78211657 0'
# Pico response: MPU: 24.60954 71.87404
# Run 3 - Command 21
# Target angles - Pitch: 20.78, Yaw: 0.00
# Actual angles - Pitch: 24.61, Yaw: 71.87
# Errors - Pitch: 3.83, Yaw: 71.87
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.55974915 0
# Pico response: Debug: Received 'ANGLE 20.55974915 0'
# Pico response: MPU: 24.02972 73.73394
# Run 3 - Command 22
# Target angles - Pitch: 20.56, Yaw: 0.00
# Actual angles - Pitch: 24.03, Yaw: 73.73
# Errors - Pitch: 3.47, Yaw: 73.73
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.32780655 0
# Pico response: Debug: Received 'ANGLE 20.32780655 0'
# Pico response: MPU: 23.12725 75.19637
# Run 3 - Command 23
# Target angles - Pitch: 20.33, Yaw: 0.00
# Actual angles - Pitch: 23.13, Yaw: 75.20
# Errors - Pitch: 2.80, Yaw: 75.20
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 20.08689611 0
# Pico response: Debug: Received 'ANGLE 20.08689611 0'
# Pico response: MPU: 23.77607 76.83388
# Run 3 - Command 24
# Target angles - Pitch: 20.09, Yaw: 0.00
# Actual angles - Pitch: 23.78, Yaw: 76.83
# Errors - Pitch: 3.69, Yaw: 76.83
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 19.83750807 0
# Pico response: Debug: Received 'ANGLE 19.83750807 0'
# Pico response: MPU: 23.74902 78.4586
# Run 3 - Command 25
# Target angles - Pitch: 19.84, Yaw: 0.00
# Actual angles - Pitch: 23.75, Yaw: 78.46
# Errors - Pitch: 3.91, Yaw: 78.46
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 19.58003523 0.126846471
# Pico response: Debug: Received 'ANGLE 19.58003523 0.126846471'
# Pico response: MPU: 23.7211 80.08206
# Run 3 - Command 26
# Target angles - Pitch: 19.58, Yaw: 0.13
# Actual angles - Pitch: 23.72, Yaw: 80.08
# Errors - Pitch: 4.14, Yaw: 79.96
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 19.31478789 0.273965544
# Pico response: Debug: Received 'ANGLE 19.31478789 0.273965544'
# Pico response: MPU: 22.80869 82.01784
# Run 3 - Command 27
# Target angles - Pitch: 19.31, Yaw: 0.27
# Actual angles - Pitch: 22.81, Yaw: 82.02
# Errors - Pitch: 3.49, Yaw: 81.74
# ...
# Pico response: MPU: 21.22118 147.1938
# Run 54 - Command 9
# Target angles - Pitch: 18.71, Yaw: 13.07
# Actual angles - Pitch: 21.22, Yaw: 147.19
# Errors - Pitch: 2.51, Yaw: 134.13
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 18.60291557 13.40307512
# Pico response: Debug: Received 'ANGLE 18.60291557 13.40307512'
# Pico response: MPU: 21.15154 151.8464
# Run 54 - Command 10
# Target angles - Pitch: 18.60, Yaw: 13.40
# Actual angles - Pitch: 21.15, Yaw: 151.85
# Errors - Pitch: 2.55, Yaw: 138.44
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 18.44676714 13.70276391
# Pico response: Debug: Received 'ANGLE 18.44676714 13.70276391'
# Pico response: MPU: 21.14072 158.1031
# Run 54 - Command 11
# Target angles - Pitch: 18.45, Yaw: 13.70
# Actual angles - Pitch: 21.14, Yaw: 158.10
# Errors - Pitch: 2.69, Yaw: 144.40
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 18.25135799 13.97395979
# Pico response: Debug: Received 'ANGLE 18.25135799 13.97395979'
# Pico response: MPU: 20.82381 165.7091
# Run 54 - Command 12
# Target angles - Pitch: 18.25, Yaw: 13.97
# Actual angles - Pitch: 20.82, Yaw: 165.71
# Errors - Pitch: 2.57, Yaw: 151.74
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 18.02524535 14.22208211
# Pico response: Debug: Received 'ANGLE 18.02524535 14.22208211'
# Pico response: MPU: 21.45743 172.1594
# Run 54 - Command 13
# Target angles - Pitch: 18.03, Yaw: 14.22
# Actual angles - Pitch: 21.46, Yaw: 172.16
# Errors - Pitch: 3.43, Yaw: 157.94
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 17.77449762 14.45099622
# Pico response: Debug: Received 'ANGLE 17.77449762 14.45099622'
# Pico response: MPU: 21.30226 178.045
# Run 54 - Command 14
# Target angles - Pitch: 17.77, Yaw: 14.45
# Actual angles - Pitch: 21.30, Yaw: 178.04
# Errors - Pitch: 3.53, Yaw: 163.59
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 17.50354493 14.66353502
# Pico response: Debug: Received 'ANGLE 17.50354493 14.66353502'
# Pico response: MPU: 21.60542 4.891739
# Run 54 - Command 15
# Target angles - Pitch: 17.50, Yaw: 14.66
# Actual angles - Pitch: 21.61, Yaw: 4.89
# Errors - Pitch: 4.10, Yaw: 9.77
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 17.21570335 14.86182279
# Pico response: Debug: Received 'ANGLE 17.21570335 14.86182279'
# Pico response: MPU: 21.07199 11.12849
# Run 54 - Command 16
# Target angles - Pitch: 17.22, Yaw: 14.86
# Actual angles - Pitch: 21.07, Yaw: 11.13
# Errors - Pitch: 3.86, Yaw: 3.73
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 16.91351032 15.04748376
# Pico response: Debug: Received 'ANGLE 16.91351032 15.04748376'
# Pico response: MPU: 21.60954 16.13486
# Run 54 - Command 17
# Target angles - Pitch: 16.91, Yaw: 15.05
# Actual angles - Pitch: 21.61, Yaw: 16.13
# Errors - Pitch: 4.70, Yaw: 1.09
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 16.59894633 15.22178087
# Pico response: Debug: Received 'ANGLE 16.59894633 15.22178087'
# Pico response: MPU: 20.90775 21.30171
# Run 54 - Command 18
# Target angles - Pitch: 16.60, Yaw: 15.22
# Actual angles - Pitch: 20.91, Yaw: 21.30
# Errors - Pitch: 4.31, Yaw: 6.08
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 16.27358559 15.38571061
# Pico response: Debug: Received 'ANGLE 16.27358559 15.38571061'
# Pico response: MPU: 21.26124 27.31782
# Run 54 - Command 19
# Target angles - Pitch: 16.27, Yaw: 15.39
# Actual angles - Pitch: 21.26, Yaw: 27.32
# Errors - Pitch: 4.99, Yaw: 11.93
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.93870091 15.54006966
# Pico response: Debug: Received 'ANGLE 15.93870091 15.54006966'
# Pico response: MPU: 21.38465 33.95422
# Run 54 - Command 20
# Target angles - Pitch: 15.94, Yaw: 15.54
# Actual angles - Pitch: 21.38, Yaw: 33.95
# Errors - Pitch: 5.45, Yaw: 18.41
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.59533834 15.68550263
# Pico response: Debug: Received 'ANGLE 15.59533834 15.68550263'
# Pico response: MPU: 20.15337 40.07372
# Run 54 - Command 21
# Target angles - Pitch: 15.60, Yaw: 15.69
# Actual angles - Pitch: 20.15, Yaw: 40.07
# Errors - Pitch: 4.56, Yaw: 24.39
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 15.24437114 15.82253714
# Pico response: Debug: Received 'ANGLE 15.24437114 15.82253714'
# Pico response: MPU: 19.61678 45.11011
# Run 54 - Command 22
# Target angles - Pitch: 15.24, Yaw: 15.82
# Actual angles - Pitch: 19.62, Yaw: 45.11
# Errors - Pitch: 4.37, Yaw: 29.29
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.88653958 15.95161006
# Pico response: Debug: Received 'ANGLE 14.88653958 15.95161006'
# Pico response: MPU: 18.99967 51.22072
# Run 54 - Command 23
# Target angles - Pitch: 14.89, Yaw: 15.95
# Actual angles - Pitch: 19.00, Yaw: 51.22
# Errors - Pitch: 4.11, Yaw: 35.27
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.52248059 16.07308753
# Pico response: Debug: Received 'ANGLE 14.52248059 16.07308753'
# Pico response: MPU: 18.67979 56.80586
# Run 54 - Command 24
# Target angles - Pitch: 14.52, Yaw: 16.07
# Actual angles - Pitch: 18.68, Yaw: 56.81
# Errors - Pitch: 4.16, Yaw: 40.73
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 14.15275006 16.18728046
# Pico response: Debug: Received 'ANGLE 14.15275006 16.18728046'
# Pico response: MPU: 18.54616 62.07224
# Run 54 - Command 25
# Target angles - Pitch: 14.15, Yaw: 16.19
# Actual angles - Pitch: 18.55, Yaw: 62.07
# Errors - Pitch: 4.39, Yaw: 45.88
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.77783978 16.29445682
# Pico response: Debug: Received 'ANGLE 13.77783978 16.29445682'
# Pico response: MPU: 17.86036 68.78035
# Run 54 - Command 26
# Target angles - Pitch: 13.78, Yaw: 16.29
# Actual angles - Pitch: 17.86, Yaw: 68.78
# Errors - Pitch: 4.08, Yaw: 52.49
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.39819037 16.39485139
# Pico response: Debug: Received 'ANGLE 13.39819037 16.39485139'
# Pico response: MPU: 18.02347 74.82299
# Run 54 - Command 27
# Target angles - Pitch: 13.40, Yaw: 16.39
# Actual angles - Pitch: 18.02, Yaw: 74.82
# Errors - Pitch: 4.63, Yaw: 58.43
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 13.01420103 16.48867362
# Pico response: Debug: Received 'ANGLE 13.01420103 16.48867362'
# Pico response: MPU: 17.66905 80.42934
# Run 54 - Command 28
# Target angles - Pitch: 13.01, Yaw: 16.49
# Actual angles - Pitch: 17.67, Yaw: 80.43
# Errors - Pitch: 4.65, Yaw: 63.94
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 12.62623702 16.57611407
# Pico response: Debug: Received 'ANGLE 12.62623702 16.57611407'
# Pico response: MPU: 17.53988 85.97887
# Run 54 - Command 29
# Target angles - Pitch: 12.63, Yaw: 16.58
# Actual angles - Pitch: 17.54, Yaw: 85.98
# Errors - Pitch: 4.91, Yaw: 69.40
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 12.2346353 16.65734946
# Pico response: Debug: Received 'ANGLE 12.2346353 16.65734946'
# Pico response: MPU: 16.08105 91.92249
# Run 54 - Command 30
# Target angles - Pitch: 12.23, Yaw: 16.66
# Actual angles - Pitch: 16.08, Yaw: 91.92
# Errors - Pitch: 3.85, Yaw: 75.27
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.83970862 16.73254688
# Pico response: Debug: Received 'ANGLE 11.83970862 16.73254688'
# Pico response: MPU: 16.02946 98.81705
# Run 54 - Command 31
# Target angles - Pitch: 11.84, Yaw: 16.73
# Actual angles - Pitch: 16.03, Yaw: 98.82
# Errors - Pitch: 4.19, Yaw: 82.08
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.44174868 16.80186696
# Pico response: Debug: Received 'ANGLE 11.44174868 16.80186696'
# Pico response: MPU: 15.78484 105.2947
# Run 54 - Command 32
# Target angles - Pitch: 11.44, Yaw: 16.80
# Actual angles - Pitch: 15.78, Yaw: 105.29
# Errors - Pitch: 4.34, Yaw: 88.49
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 11.04102829 16.86546641
# Pico response: Debug: Received 'ANGLE 11.04102829 16.86546641'
# Pico response: MPU: 16.17829 112.744
# Run 54 - Command 33
# Target angles - Pitch: 11.04, Yaw: 16.87
# Actual angles - Pitch: 16.18, Yaw: 112.74
# Errors - Pitch: 5.14, Yaw: 95.88
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 10.63780302 16.92349985
# Pico response: Debug: Received 'ANGLE 10.63780302 16.92349985'
# Pico response: MPU: 14.80038 120.5005
# Run 54 - Command 34
# Target angles - Pitch: 10.64, Yaw: 16.92
# Actual angles - Pitch: 14.80, Yaw: 120.50
# Errors - Pitch: 4.16, Yaw: 103.58
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 10.23231228 16.97612103
# Pico response: Debug: Received 'ANGLE 10.23231228 16.97612103'
# Pico response: MPU: 13.98792 129.6232
# Run 54 - Command 35
# Target angles - Pitch: 10.23, Yaw: 16.98
# Actual angles - Pitch: 13.99, Yaw: 129.62
# Errors - Pitch: 3.76, Yaw: 112.65
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.824780198 17.02348364
# Pico response: Debug: Received 'ANGLE 9.824780198 17.02348364'
# Pico response: MPU: 14.35394 137.9773
# Run 54 - Command 36
# Target angles - Pitch: 9.82, Yaw: 17.02
# Actual angles - Pitch: 14.35, Yaw: 137.98
# Errors - Pitch: 4.53, Yaw: 120.95
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.415416235 17.06574167
# Pico response: Debug: Received 'ANGLE 9.415416235 17.06574167'
# Pico response: MPU: 14.4558 145.6309
# Run 54 - Command 37
# Target angles - Pitch: 9.42, Yaw: 17.07
# Actual angles - Pitch: 14.46, Yaw: 145.63
# Errors - Pitch: 5.04, Yaw: 128.57
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 9.004415717 17.1030495
# Pico response: Debug: Received 'ANGLE 9.004415717 17.1030495'
# Pico response: MPU: 13.89262 155.0981
# Run 54 - Command 38
# Target angles - Pitch: 9.00, Yaw: 17.10
# Actual angles - Pitch: 13.89, Yaw: 155.10
# Errors - Pitch: 4.89, Yaw: 138.00
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 8.591960319 17.13556166
# Pico response: Debug: Received 'ANGLE 8.591960319 17.13556166'
# Pico response: MPU: 13.22353 162.1725
# Run 54 - Command 39
# Target angles - Pitch: 8.59, Yaw: 17.14
# Actual angles - Pitch: 13.22, Yaw: 162.17
# Errors - Pitch: 4.63, Yaw: 145.04
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 8.178218553 17.16343248
# Pico response: Debug: Received 'ANGLE 8.178218553 17.16343248'
# Pico response: MPU: 12.95033 168.583
# Run 54 - Command 40
# Target angles - Pitch: 8.18, Yaw: 17.16
# Actual angles - Pitch: 12.95, Yaw: 168.58
# Errors - Pitch: 4.77, Yaw: 151.42
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 7.763346287 17.18681557
# Pico response: Debug: Received 'ANGLE 7.763346287 17.18681557'
# Pico response: MPU: 12.50244 176.6479
# Run 54 - Command 41
# Target angles - Pitch: 7.76, Yaw: 17.19
# Actual angles - Pitch: 12.50, Yaw: 176.65
# Errors - Pitch: 4.74, Yaw: 159.46
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 7.347487298 17.20586332
# Pico response: Debug: Received 'ANGLE 7.347487298 17.20586332'
# Pico response: MPU: 11.98623 6.088318
# Run 54 - Command 42
# Target angles - Pitch: 7.35, Yaw: 17.21
# Actual angles - Pitch: 11.99, Yaw: 6.09
# Errors - Pitch: 4.64, Yaw: 11.12
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.93077389 17.22072625
# Pico response: Debug: Received 'ANGLE 6.93077389 17.22072625'
# Pico response: MPU: 11.59207 13.48106
# Run 54 - Command 43
# Target angles - Pitch: 6.93, Yaw: 17.22
# Actual angles - Pitch: 11.59, Yaw: 13.48
# Errors - Pitch: 4.66, Yaw: 3.74
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.513327534 17.2315525
# Pico response: Debug: Received 'ANGLE 6.513327534 17.2315525'
# Pico response: MPU: 11.355 22.05874
# Run 54 - Command 44
# Target angles - Pitch: 6.51, Yaw: 17.23
# Actual angles - Pitch: 11.36, Yaw: 22.06
# Errors - Pitch: 4.84, Yaw: 4.83
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 6.095259558 17.23848725
# Pico response: Debug: Received 'ANGLE 6.095259558 17.23848725'
# Pico response: MPU: 11.5066 30.80062
# Run 54 - Command 45
# Target angles - Pitch: 6.10, Yaw: 17.24
# Actual angles - Pitch: 11.51, Yaw: 30.80
# Errors - Pitch: 5.41, Yaw: 13.56
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 5.676671846 17.24167226
# Pico response: Debug: Received 'ANGLE 5.676671846 17.24167226'
# Pico response: MPU: 11.31588 37.4545
# Run 54 - Command 46
# Target angles - Pitch: 5.68, Yaw: 17.24
# Actual angles - Pitch: 11.32, Yaw: 37.45
# Errors - Pitch: 5.64, Yaw: 20.21
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 5.257657562 17.24124547
# Pico response: Debug: Received 'ANGLE 5.257657562 17.24124547'
# Pico response: MPU: 10.28599 44.21897
# Run 54 - Command 47
# Target angles - Pitch: 5.26, Yaw: 17.24
# Actual angles - Pitch: 10.29, Yaw: 44.22
# Errors - Pitch: 5.03, Yaw: 26.98
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.838301856 17.23734063
# Pico response: Debug: Received 'ANGLE 4.838301856 17.23734063'
# Pico response: MPU: 9.539116 52.11142
# Run 54 - Command 48
# Target angles - Pitch: 4.84, Yaw: 17.24
# Actual angles - Pitch: 9.54, Yaw: 52.11
# Errors - Pitch: 4.70, Yaw: 34.87
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 4.418682572 17.23008702
# Pico response: Debug: Received 'ANGLE 4.418682572 17.23008702'
# Pico response: MPU: 9.330864 58.38106
# Run 54 - Command 49
# Target angles - Pitch: 4.42, Yaw: 17.23
# Actual angles - Pitch: 9.33, Yaw: 58.38
# Errors - Pitch: 4.91, Yaw: 41.15
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 3.998870925 17.21960927
# Pico response: Debug: Received 'ANGLE 3.998870925 17.21960927'
# Pico response: MPU: 9.192566 69.5648
# Run 54 - Command 50
# Target angles - Pitch: 4.00, Yaw: 17.22
# Actual angles - Pitch: 9.19, Yaw: 69.56
# Errors - Pitch: 5.19, Yaw: 52.35
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 3.578932155 17.20602719
# Pico response: Debug: Received 'ANGLE 3.578932155 17.20602719'
# Pico response: MPU: 8.686157 79.28306
# Run 54 - Command 51
# Target angles - Pitch: 3.58, Yaw: 17.21
# Actual angles - Pitch: 8.69, Yaw: 79.28
# Errors - Pitch: 5.11, Yaw: 62.08
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 3.158926147 17.18945569
# Pico response: Debug: Received 'ANGLE 3.158926147 17.18945569'
# Pico response: MPU: 7.856842 88.41471
# Run 54 - Command 52
# Target angles - Pitch: 3.16, Yaw: 17.19
# Actual angles - Pitch: 7.86, Yaw: 88.41
# Errors - Pitch: 4.70, Yaw: 71.23
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 2.738908009 17.17000475
# Pico response: Debug: Received 'ANGLE 2.738908009 17.17000475'
# Pico response: MPU: 8.142525 97.50101
# Run 54 - Command 53
# Target angles - Pitch: 2.74, Yaw: 17.17
# Actual angles - Pitch: 8.14, Yaw: 97.50
# Errors - Pitch: 5.40, Yaw: 80.33
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 2.318928614 17.14777941
# Pico response: Debug: Received 'ANGLE 2.318928614 17.14777941'
# Pico response: MPU: 7.199707 106.0583
# Run 54 - Command 54
# Target angles - Pitch: 2.32, Yaw: 17.15
# Actual angles - Pitch: 7.20, Yaw: 106.06
# Errors - Pitch: 4.88, Yaw: 88.91
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.8990351 17.12287986
# Pico response: Debug: Received 'ANGLE 1.8990351 17.12287986'
# Pico response: MPU: 7.493652 113.3538
# Run 54 - Command 55
# Target angles - Pitch: 1.90, Yaw: 17.12
# Actual angles - Pitch: 7.49, Yaw: 113.35
# Errors - Pitch: 5.59, Yaw: 96.23
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.479271332 17.09540144
# Pico response: Debug: Received 'ANGLE 1.479271332 17.09540144'
# Pico response: MPU: 6.138931 120.4487
# Run 54 - Command 56
# Target angles - Pitch: 1.48, Yaw: 17.10
# Actual angles - Pitch: 6.14, Yaw: 120.45
# Errors - Pitch: 4.66, Yaw: 103.35
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 1.059678312 17.06543485
# Pico response: Debug: Received 'ANGLE 1.059678312 17.06543485'
# Pico response: MPU: 7.906487 128.676
# Run 54 - Command 57
# Target angles - Pitch: 1.06, Yaw: 17.07
# Actual angles - Pitch: 7.91, Yaw: 128.68
# Errors - Pitch: 6.85, Yaw: 111.61
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.64029457 17.03306616
# Pico response: Debug: Received 'ANGLE 0.64029457 17.03306616'
# Pico response: MPU: 6.08844 136.816
# Run 54 - Command 58
# Target angles - Pitch: 0.64, Yaw: 17.03
# Actual angles - Pitch: 6.09, Yaw: 136.82
# Errors - Pitch: 5.45, Yaw: 119.78
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.221156495 16.99837704
# Pico response: Debug: Received 'ANGLE 0.221156495 16.99837704'
# Pico response: MPU: 6.966026 145.648
# Run 54 - Command 59
# Target angles - Pitch: 0.22, Yaw: 17.00
# Actual angles - Pitch: 6.97, Yaw: 145.65
# Errors - Pitch: 6.74, Yaw: 128.65
# Corrected servo yaw: 80.00
#
# Pico response: ANGLE 0.011628504 16.98064598
# Pico response: Debug: Received 'ANGLE 0.011628504 16.98064598'
# Pico response: MPU: 7.471291 153.514
# Run 54 - Command 60
# Target angles - Pitch: 0.01, Yaw: 16.98
# Actual angles - Pitch: 7.47, Yaw: 153.51
# Errors - Pitch: 7.46, Yaw: 136.53
# Corrected servo yaw: 80.00
#
# All results saved to combined_results.csv
# Serial connection closed

# %%
# for second set of data
import serial
import time
import math
import csv
from gekko import GEKKO
import numpy as np
import matplotlib.pyplot as plt

ser = serial.Serial(
    port='COM6',
    baudrate=115200,
    timeout=1
)

# List to store results for each run
results = {i: [] for i in range(1, 55)}  # Initialize results dict for 54 runs

def send_command(command):
    ser.reset_input_buffer()
    ser.write(f"{command}\r\n".encode())
    time.sleep(0.01)
    
    while ser.in_waiting:
        response = ser.readline().decode().strip()
        if response:
            print(f"Pico response: {response}")
            if response.startswith("MPU:"):
                return [float(x) for x in response[4:].split()]
    return None

def send_angles(pitch, yaw):
    command = f"ANGLE {pitch} {yaw}"
    return send_command(command)

def setup_mpc():
    m = GEKKO()
    m.time = np.linspace(0, 2, 21)
    
    yaw_measured = m.CV(value=0)
    servo_angle = m.MV(value=90)
    
    servo_angle.LOWER = 0
    servo_angle.UPPER = 180
    servo_angle.DMAX = 10
    servo_angle.STATUS = 1
    
    yaw_measured.STATUS = 1
    
    K = 0.8
    tau = 0.5
    m.Equation(tau * yaw_measured.dt() == -yaw_measured + K * servo_angle)
    
    m.options.IMODE = 6
    m.options.CV_TYPE = 2
    m.options.NODES = 3
    
    return m, yaw_measured, servo_angle

def correct_yaw_mpc(target_yaw, actual_yaw, current_servo_yaw):
    if not hasattr(correct_yaw_mpc, 'mpc'):
        correct_yaw_mpc.mpc, correct_yaw_mpc.yaw_cv, correct_yaw_mpc.servo_mv = setup_mpc()
    
    m = correct_yaw_mpc.mpc
    yaw_cv = correct_yaw_mpc.yaw_cv
    servo_mv = correct_yaw_mpc.servo_mv
    
    yaw_cv.MEAS = actual_yaw
    yaw_cv.SP = target_yaw
    
    try:
        m.solve(disp=False)
        new_servo_yaw = float(servo_mv.NEWVAL)
        new_servo_yaw = max(0, min(180, new_servo_yaw))
        return new_servo_yaw
    except:
        print("MPC solution failed, using current angle")
        return current_servo_yaw

try:
    time.sleep(0.01)
    ser.reset_input_buffer()
    
    # Read from angle_tracking_all_hr.csv
    ########
    # INPUT FILE HERE
    ########
    with open('angle_tracking_all_hr.csv', 'r') as file:
        csv_reader = csv.DictReader(file)
        
        # Process each run (1-54)
        for run in range(1, 55):
            # Reset pitch to 25 degrees before each run
            _ = send_angles(25, 90)  # Reset to 25 degrees pitch, neutral yaw
            time.sleep(0.5)  # Give time for servo to reach position
            
            command_count = 0
            pitch_col = f'pitch_{run}'
            yaw_col = f'yaw_{run}'
            
            # Reset file pointer for each run
            file.seek(0)
            next(csv_reader)  # Skip header
            
                
                current_servo_yaw = target_yaw
                actual_angles = send_angles(target_pitch, current_servo_yaw)
                
                    
                target_pitch = float(row[pitch_col])
                target_yaw = float(row[yaw_col])
                
                # Ensure angles stay within bounds
                target_pitch = max(0, min(180, target_pitch))
                target_yaw = max(0, min(180, target_yaw))
                
                current_servo_yaw = target_yaw
                actual_angles = send_angles(target_pitch, current_servo_yaw)
                
                if actual_angles:
                    actual_pitch, actual_yaw = actual_angles
                    pitch_error = abs(target_pitch - actual_pitch)
                    yaw_error = abs(target_yaw - actual_yaw)
                    
                    # Store results for this run
                    results[run].append({
                        f'pitch_{run}': target_pitch,
                        f'measured_pitch_{run}': actual_pitch,
                        f'err_{run}': pitch_error,
                        f'yaw_{run}': target_yaw,
                        f'measured_yaw_{run}': actual_yaw,
                        f'yaw_err_{run}': yaw_error
                    })
                    
                    print(f"Run {run} - Command {command_count + 1}")
                    print(f"Target angles - Pitch: {target_pitch:.2f}, Yaw: {target_yaw:.2f}")
                    print(f"Actual angles - Pitch: {actual_pitch:.2f}, Yaw: {actual_yaw:.2f}")
                    print(f"Errors - Pitch: {pitch_error:.2f}, Yaw: {yaw_error:.2f}")
                    
                    current_servo_yaw = correct_yaw_mpc(target_yaw, actual_yaw, current_servo_yaw)
                    print(f"Corrected servo yaw: {current_servo_yaw:.2f}\n")
                
                command_count += 1
                time.sleep(0.01)

except KeyboardInterrupt:
    print("\nOperation interrupted by user")

finally:
    # Save all results to a single CSV
    all_data = []
    max_rows = 0
    
    # First find the maximum number of rows across all runs
    for run in range(1, 55):
        if results[run]:
            max_rows = max(max_rows, len(results[run]))
    
    # Create the combined data
    for i in range(max_rows):
        row_data = {}
        for run in range(1, 55):
            if results[run] and i < len(results[run]):
                row_data.update(results[run][i])
        all_data.append(row_data)
    
    if all_data:
        #########
        # OUTPUT FILE NAME HERE
        ########
        filename = 'combined_results2.csv'  # Changed filename
        fieldnames = []
        for run in range(1, 55):
            if results[run]:
                fieldnames.extend(list(results[run][0].keys()))
        
        with open(filename, 'w', newline='') as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(all_data)
            print(f"All results saved to {filename}")
    
    ser.close()
    print("Serial connection closed")
# Out:
#   Input In [3]
#     current_servo_yaw = target_yaw
#     ^
# IndentationError: unexpected indent

# %%
import serial
import time
import math
import csv
from gekko import GEKKO
import numpy as np
import matplotlib.pyplot as plt

# Configure serial connection
ser = serial.Serial(
    port='COM6',
    baudrate=115200,
    timeout=1
)

def perform_yaw_sensitivity_analysis():
    # Define test parameters
    K_values = [0.5, 0.8, 1.0]  # Process gains 
    tau_values = [0.3, 0.5, 0.7]  # Time constants
    results = {}

    # Run simulations for different parameter combinations
    for K in K_values:
        for tau in tau_values:
            m = GEKKO()
            m.time = np.linspace(0, 5, 51)  # 5 second simulation
            
            # System variables
            yaw = m.Var(value=90)  # Start at center position
            servo_input = m.MV(value=90)
            servo_input.STATUS = 0  # Not used for optimization
            
            # System dynamics
            m.Equation(tau * yaw.dt() == -yaw + K * servo_input)
            
            # Apply step input
            servo_input.VALUE = 135  # 45 degree step change
            
            # Simulation settings
            m.options.IMODE = 4  # Dynamic simulation mode
            m.solve(disp=False)
            
            # Store results
            results[f'K={K}, τ={tau}'] = {
                'time': m.time,
                'yaw': yaw.VALUE,
                'input': servo_input.VALUE
            }

    return results

# Run sensitivity analysis
sensitivity_results = perform_yaw_sensitivity_analysis()

# Plot results
plt.figure(figsize=(12, 6))
for label, data in sensitivity_results.items():
    plt.plot(data['time'], data['yaw'], label=label)
plt.xlabel('Time (s)')
plt.ylabel('Yaw Angle (degrees)')
plt.title('Yaw Sensitivity Analysis: Response to 45° Step Input')
plt.legend()
plt.grid(True)
plt.savefig('yaw_sensitivity.png')
plt.close()

# Close serial connection
ser.close()
print("Analysis complete. Results saved to yaw_sensitivity.png")
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# Input In [2], in <cell line: 10>()
#       7 import matplotlib.pyplot as plt
#       9 # Configure serial connection
# ---> 10 ser = serial.Serial(
#      11     port='COM6',
#      12     baudrate=115200,
#      13     timeout=1
#      14 )
#      16 def perform_yaw_sensitivity_analysis():
#      17     # Define test parameters
#      18     K_values = [0.5, 0.8, 1.0]  # Process gains
#
# File c:\Users\masaz\miniconda3\lib\site-packages\serial\serialwin32.py:33, in Serial.__init__(self, *args, **kwargs)
#      31 self._overlapped_read = None
#      32 self._overlapped_write = None
# ---> 33 super(Serial, self).__init__(*args, **kwargs)
#
# File c:\Users\masaz\miniconda3\lib\site-packages\serial\serialutil.py:244, in SerialBase.__init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     241     raise ValueError('unexpected keyword arguments: {!r}'.format(kwargs))
#     243 if port is not None:
# --> 244     self.open()
#
# File c:\Users\masaz\miniconda3\lib\site-packages\serial\serialwin32.py:64, in Serial.open(self)
#      62 if self._port_handle == win32.INVALID_HANDLE_VALUE:
#      63     self._port_handle = None    # 'cause __del__ is called anyway
# ---> 64     raise SerialException("could not open port {!r}: {!r}".format(self.portstr, ctypes.WinError()))
#      66 try:
#      67     self._overlapped_read = win32.OVERLAPPED()
#
# SerialException: could not open port 'COM6': FileNotFoundError(2, 'The system cannot find the file specified.', None, 2)

# %%
if True:
    # Perform sensitivity analysis
    sensitivity_results = perform_sensitivity_analysis()
    
    # Plot sensitivity analysis results
    plt.figure(figsize=(12, 6))
    for label, data in sensitivity_results.items():
        plt.plot(data['time'], data['pitch'], label=label)
    plt.xlabel('Time (s)')
    plt.ylabel('Pitch Angle')
    plt.title('Sensitivity Analysis: System Response to Step Change')
    plt.legend()
    plt.grid(True)
    plt.savefig('sensitivity_analysis3.png')
    plt.close()
    
    # Simulate control optimization
    optimization_results = simulate_control_optimization()
    
    # Plot optimization results
    plt.figure(figsize=(12, 6))
    plt.subplot(2, 1, 1)
    plt.plot(optimization_results['time'], optimization_results['pitch'], 'b-', label='Pitch')
    plt.plot(optimization_results['time'], optimization_results['setpoint'], 'r--', label='Setpoint')
    plt.ylabel('Pitch Angle')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(2, 1, 2)
    plt.plot(optimization_results['time'], optimization_results['servo'], 'g-', label='Servo Command')
    plt.xlabel('Time (s)')
    plt.ylabel('Servo Angle')
    plt.legend()
    plt.grid(True)
    plt.savefig('optimization_results3.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 if True:
#       2     # Perform sensitivity analysis
# ----> 3     sensitivity_results = perform_sensitivity_analysis()
#       5     # Plot sensitivity analysis results
#       6     plt.figure(figsize=(12, 6))
#
# NameError: name 'perform_sensitivity_analysis' is not defined

# %%
with open('results.csv', 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=['Target Pitch', 'Actual Pitch', 'Error'])
    writer.writeheader()
    writer.writerows(results)
    print("\nResults saved to results.csv")
# Out:
# Results saved to results.csv
